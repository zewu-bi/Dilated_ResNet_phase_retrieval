# %%
# Cell 1: imports

import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
from torch.utils.data import DataLoader, random_split
from torch.utils.tensorboard import SummaryWriter
from torch.serialization import add_safe_globals

from src.dilated_resnet import (
    CTRDataset,
    DilatedResBlock,
    Dilated_CNN_ResNet,
    AsinhMSEWithPhysicsLoss,
    train_one_epoch,
    evaluate,
)
from src.form_factor_utils import (
    l1_nonneg_normalize,
    compute_form_factor,
    k_to_THz,
)
from src.reconstruction_utils import (
    fwhm_center,
    align_by_fwhm,
    weighted_error,
    gerchberg_saxton_1d_torch,
    forward_spectrum_fft,
    resample_linear,
)

from src.quant_eval_plots import (
    build_quantitative_cache,
    print_cache_summary,
)

# %%
# Cell 2: basic config

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# Cell 3: paths, hyperparameters, and shared settings

img_folder    = "./dataset/G1_G2/img"
target_folder = "./dataset/G1_G2/target"

num_exp = 40
sequence_length = 256
batch_size = 256
num_epochs = 200
learning_rate = 1e-3
val_ratio = 0.2
split_seed = 42

# shared plotting / physics settings
dx_um = 0.15
f_min = 50
f_max = 230
f_display_max = 250
pad_factor = 10

# %%
# Cell 4: dataset + fixed train/val split + dataloaders

img_files = sorted([f for f in os.listdir(img_folder) if f.endswith(".pt")])
tgt_files = sorted([f for f in os.listdir(target_folder) if f.endswith(".pt")])

# print("Number of img files   :", len(img_files))
# print("Number of target files:", len(tgt_files))

full_dataset = CTRDataset(img_folder, target_folder, img_files, tgt_files, seq_len=sequence_length)
print("Total samples in dataset:", len(full_dataset))

num_total = len(full_dataset)
num_val = int(num_total * val_ratio)
num_train = num_total - num_val

split_generator = torch.Generator().manual_seed(split_seed)
train_dataset, val_dataset = random_split(
    full_dataset,
    [num_train, num_val],
    generator=split_generator,
)

print(f"Train samples: {num_train}, Val samples: {num_val}")
# print("First 5 val indices:", val_dataset.indices[:5])

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Total samples in dataset: 90000
# Train samples: 72000, Val samples: 18000

# %%
# Cell 5: model + loss + optimizer + train/eval loops

model = Dilated_CNN_ResNet(in_ch=1, base_ch=64).to(device)
criterion = AsinhMSEWithPhysicsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
# Cell 6: train and save checkpoints

writer = SummaryWriter(log_dir="./logs/exp{}".format(num_exp))
train_losses = []
val_losses = []

for epoch in range(1, num_epochs + 1):
    train_loss = train_one_epoch(model, train_loader, optimizer, criterion, device)
    val_loss = evaluate(model, val_loader, criterion, device)

    train_losses.append(train_loss)
    val_losses.append(val_loss)

    writer.add_scalar("Loss/train", train_loss, epoch)
    writer.add_scalar("Loss/val", val_loss, epoch)

    print(f"Epoch [{epoch:03d}/{num_epochs}] Train Loss: {train_loss:.6f}  |  Val Loss: {val_loss:.6f}")

    os.makedirs("./model/exp{}".format(num_exp), exist_ok=True)
    torch.save(model, "./model/exp{}/Dilated_ResNet_{}.pth".format(num_exp, epoch))

writer.close()
print("Training finished. Logs saved to ./logs/exp{}".format(num_exp))
# Out:
# Epoch [001/200] Train Loss: 0.029697  |  Val Loss: 0.017578
# Epoch [002/200] Train Loss: 0.012981  |  Val Loss: 0.010712
# Epoch [003/200] Train Loss: 0.009476  |  Val Loss: 0.008855
# Epoch [004/200] Train Loss: 0.008439  |  Val Loss: 0.008105
# Epoch [005/200] Train Loss: 0.007687  |  Val Loss: 0.007365
# Epoch [006/200] Train Loss: 0.007233  |  Val Loss: 0.007023
# Epoch [007/200] Train Loss: 0.006965  |  Val Loss: 0.006636
# Epoch [008/200] Train Loss: 0.006532  |  Val Loss: 0.006390
# Epoch [009/200] Train Loss: 0.006274  |  Val Loss: 0.006221
# Epoch [010/200] Train Loss: 0.006056  |  Val Loss: 0.006031
# Epoch [011/200] Train Loss: 0.005913  |  Val Loss: 0.006060
# Epoch [012/200] Train Loss: 0.005724  |  Val Loss: 0.005771
# Epoch [013/200] Train Loss: 0.005498  |  Val Loss: 0.005505
# Epoch [014/200] Train Loss: 0.005355  |  Val Loss: 0.005708
# Epoch [015/200] Train Loss: 0.005281  |  Val Loss: 0.004993
# Epoch [016/200] Train Loss: 0.005049  |  Val Loss: 0.005893
# ...

# %%
# Cell 7: load model

add_safe_globals([DilatedResBlock, Dilated_CNN_ResNet])

model_path = "./model/exp{}/Dilated_ResNet_{}.pth".format(num_exp, num_epochs)
print("Loading model:", model_path)

model = torch.load(model_path, map_location=device, weights_only=False)
# Out:
# Loading model: ./model/exp40/Dilated_ResNet_200.pth

# %%
# Cell 8: validation visualization (merged, keep only the 3x2 figure)

model.eval()

vis_indices = [100, 101, 102]

fig, axes = plt.subplots(3, 2, figsize=(13, 11))
fig.suptitle("Validation Set: Multi-Gaussian Reconstruction under Finite Bandwidth", fontsize=15)

for row, idx in enumerate(vis_indices):
    img, tgt = val_dataset[idx]
    img = img.unsqueeze(0).to(device)
    tgt = l1_nonneg_normalize(tgt.squeeze().cpu().numpy())

    with torch.no_grad():
        pred = model(img).squeeze().cpu().numpy()
    pred = l1_nonneg_normalize(pred)

    z = np.arange(len(tgt)) * dx_um

    ax_left = axes[row, 0]
    ax_left.plot(z, tgt, linewidth=2, label="True")
    ax_left.plot(z, pred, "--", linewidth=2, color="orange", label="Reconstruction")
    ax_left.set_xlabel("z (μm)")
    ax_left.set_ylabel("Normalized charge")
    ax_left.set_title(f"Validation Sample {idx}")
    ax_left.grid(True)
    ax_left.legend()

    k_rec, F2_rec = compute_form_factor(z, pred, pad_factor=pad_factor)
    freq_rec = k_to_THz(k_rec)

    mask_full = (freq_rec >= 0) & (freq_rec <= f_display_max)
    freq_full = freq_rec[mask_full]
    F2_full = F2_rec[mask_full]

    spectrum_measured = img.squeeze().cpu().numpy()
    freq_meas = np.linspace(f_min, f_max, len(spectrum_measured))

    mask_band_full = (freq_full >= f_min) & (freq_full <= f_max)
    scale_forward = np.max(F2_full[mask_band_full]) if np.any(mask_band_full) else np.max(F2_full)
    scale_measured = np.max(spectrum_measured)

    scale_forward = scale_forward if scale_forward > 0 else 1.0
    scale_measured = scale_measured if scale_measured > 0 else 1.0

    ax_right = axes[row, 1]
    ax_right.axvspan(0, f_min, color="blue", alpha=0.08)
    ax_right.axvspan(f_max, f_display_max, color="blue", alpha=0.08)
    ax_right.plot(freq_meas, spectrum_measured / scale_measured, linewidth=2, label="True")
    ax_right.plot(freq_full, F2_full / scale_forward, "--", linewidth=2, color="orange", label="Reconstruction")
    ax_right.set_xlim(0, f_display_max)
    ax_right.set_xlabel("Frequency (THz)")
    ax_right.set_ylabel("Normalized |F|² (band-max)")
    ax_right.set_title("Spectral Consistency")
    ax_right.grid(True)
    ax_right.legend()

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
# Cell 9: CNN Noise Robustness (Peak-weighted error)

model.eval()

box_main = "#3A6EA5"
box_fill = "#9DBBD9"
median_color = "#2C4E73"

# -----------------------------------------
# Select one double-Gaussian sample
# -----------------------------------------
rand_idx = 102


img, tgt = val_dataset[rand_idx]
img = img.unsqueeze(0).to(device)
tgt = tgt.squeeze().cpu().numpy()

N = len(tgt)
z = np.arange(N) * dx_um

# ---- L1 normalization ----
tgt = np.clip(tgt, 0, None)
tgt_norm = tgt / np.sum(tgt)
tgt_norm_max = tgt_norm / np.max(tgt_norm)

# -----------------------------------------
# FWHM alignment
# -----------------------------------------
c_true = fwhm_center(tgt_norm_max, z)

# -----------------------------------------
# Representative reconstructions (LEFT 不动)
# -----------------------------------------
rep_levels = [1e-4, 1e-3, 1e-2]
rep_profiles = []

for nl in rep_levels:

    torch.manual_seed(0)
    noise = nl * torch.randn_like(img)
    img_noisy = torch.clamp(img + noise, min=0.0)

    with torch.no_grad():
        pred = model(img_noisy).squeeze().cpu().numpy()

    pred = np.clip(pred, 0, None)
    pred = pred / np.sum(pred)

    pred_aligned = align_by_fwhm(pred, z, c_true, dx_um)
    rep_profiles.append((nl, pred_aligned))

# -----------------------------------------
# New error metric (peak-weighted L2)
# -----------------------------------------

# 权重 = true profile（强调结构）
weight = tgt_norm
weight = weight / np.max(weight)

# -----------------------------------------
# Statistical scan
# -----------------------------------------
noise_levels = np.logspace(-4, -2, 15)
n_trials = 50
all_errors = []

for nl in noise_levels:

    trial_errors = []

    for seed in range(n_trials):

        torch.manual_seed(seed)
        noise = nl * torch.randn_like(img)
        img_noisy = torch.clamp(img + noise, min=0.0)

        with torch.no_grad():
            pred = model(img_noisy).squeeze().cpu().numpy()

        pred = np.clip(pred, 0, None)
        pred = pred / np.sum(pred)

        pred_aligned = align_by_fwhm(pred, z, c_true, dx_um)

        err = weighted_error(pred_aligned, tgt_norm, weight)
        trial_errors.append(err)

    all_errors.append(trial_errors)

# =========================================
# Plot
# =========================================

fig, axes = plt.subplots(1, 2, figsize=(13, 5))

# ---- LEFT (不动) ----
ax1 = axes[0]

ax1.plot(z, tgt_norm, "k--", linewidth=2, label="Ground truth")

for nl, r in rep_profiles:
    ax1.plot(z, r, linewidth=2, label=f"{nl*100:.2f}% noise")

ax1.set_xlabel("z (μm)")
ax1.set_ylabel("Normalized charge")
ax1.set_title("CNN reconstruction under spectral noise")
ax1.legend(frameon=False)
ax1.grid(alpha=0.3)

# ---- RIGHT (new metric) ----
ax2 = axes[1]

idx = np.arange(len(noise_levels))

box = ax2.boxplot(
    all_errors,
    positions=idx,
    widths=0.6,
    patch_artist=True,
    showfliers=False,
    medianprops=dict(color=median_color, linewidth=2),
    whiskerprops=dict(color=box_main, linewidth=1.5),
    capprops=dict(color=box_main, linewidth=1.5),
    boxprops=dict(color=box_main, linewidth=1.5),
)

for patch in box["boxes"]:
    patch.set_facecolor(box_fill)
    patch.set_alpha(0.6)

medians = [np.median(e) for e in all_errors]
ax2.plot(idx, medians, color=median_color, linewidth=2.2, marker="o", markersize=4)

ax2.set_xlabel("Noise level")
ax2.set_ylabel("Peak-weighted relative error")
ax2.set_title("Structure preservation under spectral noise")

ax2.set_xticks([0, 7, 14])
ax2.set_xticklabels([r"$10^{-4}$", r"$10^{-3}$", r"$10^{-2}$"])

ax2.grid(axis="y", linestyle="--", alpha=0.25)

plt.tight_layout()
plt.show()

# %%
# Cell 10: CNN (unchanged) + GS (Figure2-style forward)

model.eval()

gs_iters = 2000
gs_seed = 1
use_support = True
support_width_um = 30

vis_indices = [101, 102, 103]

# -----------------------------------------
# Timing containers
# -----------------------------------------
nn_times = []
gs_times = []

# -----------------------------------------
# Create figure
# -----------------------------------------
fig, axes = plt.subplots(3, 1, figsize=(10, 12))

for ax, i in zip(axes, vis_indices):

    img, tgt = val_dataset[i]
    img = img.unsqueeze(0).to(device)
    tgt_np = tgt.squeeze().cpu().numpy()

    tgt_np = np.clip(tgt_np, 0, None)
    tgt_np = tgt_np / np.sum(tgt_np)

    # ===============================
    # CNN timing
    # ===============================
    torch.cuda.synchronize() if device.type == "cuda" else None
    start_nn = time.perf_counter()

    with torch.no_grad():
        pred_cnn = model(img)

    torch.cuda.synchronize() if device.type == "cuda" else None
    end_nn = time.perf_counter()

    nn_time_ms = (end_nn - start_nn) * 1000
    nn_times.append(nn_time_ms)

    pred_cnn = pred_cnn.squeeze().cpu().numpy()
    pred_cnn = np.clip(pred_cnn, 0, None)
    pred_cnn = pred_cnn / np.sum(pred_cnn)

    # -----------------------------------------
    # GS forward
    # -----------------------------------------
    rho_true = torch.tensor(tgt_np, dtype=torch.float32, device=device)

    I_meas, _ = forward_spectrum_fft(rho_true)
    I_meas = I_meas.real
    I_meas = I_meas / torch.max(I_meas)

    N = rho_true.numel()
    z_um = (np.arange(N) - N // 2) * dx_um

    if use_support:
        support_mask_np = (np.abs(z_um) <= support_width_um / 2).astype(np.float32)
        support_mask = torch.tensor(support_mask_np, dtype=torch.float32, device=device)
    else:
        support_mask = None

    torch.manual_seed(gs_seed)

    # ===============================
    # GS timing
    # ===============================
    torch.cuda.synchronize() if device.type == "cuda" else None
    start_gs = time.perf_counter()

    rho_gs = gerchberg_saxton_1d_torch(
        I_meas=I_meas,
        n_iters=gs_iters,
        support_mask=support_mask,
        smooth=True,
        device=device,
    )

    torch.cuda.synchronize() if device.type == "cuda" else None
    end_gs = time.perf_counter()

    gs_time_ms = (end_gs - start_gs) * 1000
    gs_times.append(gs_time_ms)

    rho_gs = rho_gs.detach().cpu().numpy()
    rho_gs = np.clip(rho_gs, 0, None)
    rho_gs = rho_gs / np.sum(rho_gs)

    # -----------------------------------------
    # Plot
    # -----------------------------------------
    ax.plot(z_um, tgt_np, linewidth=2, label="Target (Val)")
    ax.plot(z_um, pred_cnn, linestyle="--", linewidth=2, label="CNN")
    ax.plot(z_um, rho_gs, linestyle="-.", linewidth=2,
            label=f"GS (seed={gs_seed}, iters={gs_iters}"
                  + (f", support={support_width_um}μm" if use_support else "") + ")")

    ax.set_xlabel("z (μm)")
    ax.set_ylabel("L1-normalized ρ(z)")
    ax.set_title(f"Validation Sample {i}")
    ax.grid(True)
    ax.legend()

plt.tight_layout()
plt.show()

# =========================================
# Timing statistics
# =========================================

nn_times = np.array(nn_times)
gs_times = np.array(gs_times)

print("=========================================")
print("Timing statistics over selected samples")
print("=========================================")
print(f"GS (2000 iterations):           {gs_times.mean():.2f} ± {gs_times.std():.2f} ms")
print(f"Neural network (1 forward pass):{nn_times.mean():.2f} ± {nn_times.std():.2f} ms")
# Out:
# ...
# Timing statistics over selected samples
# ...
# GS (2000 iterations):           691.77 ± 227.51 ms
# Neural network (1 forward pass):1.29 ± 0.11 ms

# %%
# Cell X: Dataset-level quantitative comparison (single / double only)
# Uses the same 1D dilated resnet + GS interfaces already used above.

import re
from collections import defaultdict

model.eval()

# -----------------------------
# Settings (adjust if needed)
# -----------------------------
max_per_group = 500           # max number of validation samples per group
gs_seeds = [0, 1, 2, 3, 4]   # multi-seed GS to show procedural variability
gs_iters = 2000
use_support = True
support_width_um = 30.0

# -----------------------------
# Helper functions
# -----------------------------
def _to_np(x):
    if isinstance(x, torch.Tensor):
        return x.detach().cpu().numpy()
    return np.asarray(x)

def normalize_profile(y):
    y = np.clip(_to_np(y), 0, None).astype(np.float64)
    s = y.sum()
    if s <= 0:
        return np.zeros_like(y)
    return y / s

def max_normalize(y):
    y = np.clip(_to_np(y), 0, None).astype(np.float64)
    m = y.max()
    return y / m if m > 0 else y

def safe_fwhm_center(y, z):
    y_max = max_normalize(y)
    try:
        return fwhm_center(y_max, z)
    except Exception:
        s = y_max.sum()
        return float((z * y_max).sum() / s) if s > 0 else float(z[len(z)//2])

def align_to_true_center(pred, true, z, dx_um):
    c_true = safe_fwhm_center(true, z)
    try:
        return align_by_fwhm(pred, z, c_true, dx_um)
    except Exception:
        return pred

def profile_nrmse(pred, true):
    denom = np.linalg.norm(true)
    if denom <= 0:
        return np.nan
    return np.linalg.norm(pred - true) / denom

def band_spectral_error(profile, measured_band):
    # measured_band is the band-limited validation input (length 256)
    N = len(profile)
    z = np.arange(N) * dx_um
    k_rec, F2_rec = compute_form_factor(z, profile, pad_factor=pad_factor)
    freq_rec = k_to_THz(k_rec)

    freq_meas = np.linspace(f_min, f_max, len(measured_band))
    mask = (freq_rec >= f_min) & (freq_rec <= f_max)

    if not np.any(mask):
        return np.nan

    freq_band = freq_rec[mask]
    F2_band = np.clip(F2_rec[mask], 0, None)

    # interpolate forward spectrum onto the measurement grid
    F2_interp = np.interp(freq_meas, freq_band, F2_band)

    meas = np.clip(_to_np(measured_band), 0, None).astype(np.float64)
    # band-max normalization, consistent with your existing figures
    meas = meas / max(meas.max(), 1e-12)
    F2_interp = F2_interp / max(F2_interp.max(), 1e-12)

    denom = np.linalg.norm(meas)
    if denom <= 0:
        return np.nan
    return np.linalg.norm(F2_interp - meas) / denom

def fwhm_width(y, z):
    y = max_normalize(y)
    if y.max() <= 0:
        return np.nan
    mask = y >= 0.5
    idx = np.where(mask)[0]
    if len(idx) < 2:
        return np.nan
    return float(z[idx[-1]] - z[idx[0]])

def two_peak_separation(y, z, min_sep_um=2.0, min_height_rel=0.15):
    y = max_normalize(y)
    if y.max() <= 0:
        return np.nan

    min_sep_pts = max(1, int(round(min_sep_um / dx_um)))
    peak_idx = []

    for i in range(1, len(y) - 1):
        if y[i] >= y[i - 1] and y[i] >= y[i + 1] and y[i] >= min_height_rel:
            peak_idx.append(i)

    if len(peak_idx) == 0:
        return np.nan

    # keep strongest peaks with simple non-maximum suppression
    peak_idx = sorted(peak_idx, key=lambda i: y[i], reverse=True)
    chosen = []
    for i in peak_idx:
        if all(abs(i - j) >= min_sep_pts for j in chosen):
            chosen.append(i)
        if len(chosen) == 2:
            break

    if len(chosen) < 2:
        return np.nan

    chosen = sorted(chosen)
    return float(abs(z[chosen[1]] - z[chosen[0]]))

def infer_group(sample_meta, fname):
    # Prefer metadata from beam_generator output
    if isinstance(sample_meta, dict):
        if "charges" in sample_meta and len(sample_meta["charges"]) == 1:
            return "Single"
        if "charges" in sample_meta and len(sample_meta["charges"]) == 2:
            return "Double"
        if "shapes" in sample_meta and len(sample_meta["shapes"]) == 1:
            return "Single"
        if "shapes" in sample_meta and len(sample_meta["shapes"]) == 2:
            return "Double"

    # Fallback to filename heuristics
    stem = os.path.basename(fname)
    if re.search(r'(^|[_-])G1([_-]|\.|$)', stem):
        return "Single"
    if re.search(r'(^|[_-])G2([_-]|\.|$)', stem):
        return "Double"

    return None

def make_support_mask(N, dx_um, width_um, device):
    z_um_centered = (np.arange(N) - N // 2) * dx_um
    mask_np = (np.abs(z_um_centered) <= width_um / 2).astype(np.float32)
    return torch.tensor(mask_np, dtype=torch.float32, device=device)

# -----------------------------
# Select validation samples by group
# -----------------------------
group_to_local_indices = defaultdict(list)

for local_idx, global_idx in enumerate(val_dataset.indices):
    fname = tgt_files[global_idx]
    meta_path = os.path.join(target_folder, fname)
    meta = torch.load(meta_path, map_location="cpu", weights_only=False)

    group = infer_group(meta, fname)
    if group in ("Single", "Double"):
        if len(group_to_local_indices[group]) < max_per_group:
            group_to_local_indices[group].append(local_idx)

print("Selected validation samples:")
for g in ["Single", "Double"]:
    print(f"  {g}: {len(group_to_local_indices[g])}")

# -----------------------------
# Containers
# -----------------------------
metrics = {
    "profile_nrmse": defaultdict(list),
    "spectral_error": defaultdict(list),
    "structure_error": defaultdict(list),
}
gs_seed_spread = defaultdict(list)

# -----------------------------
# Main loop
# -----------------------------
for group in ["Single", "Double"]:
    for local_idx in group_to_local_indices[group]:

        img, tgt = val_dataset[local_idx]
        img = img.unsqueeze(0).to(device)

        tgt_np = normalize_profile(tgt.squeeze())
        N = len(tgt_np)
        z = np.arange(N) * dx_um

        # ---------- 1D dilated resnet ----------
        with torch.no_grad():
            pred_nn = model(img).squeeze().cpu().numpy()

        pred_nn = normalize_profile(pred_nn)
        pred_nn = align_to_true_center(pred_nn, tgt_np, z, dx_um)

        nn_profile_err = profile_nrmse(pred_nn, tgt_np)
        nn_spec_err = band_spectral_error(pred_nn, img.squeeze().cpu().numpy())

        if group == "Single":
            true_struct = fwhm_width(tgt_np, z)
            pred_struct = fwhm_width(pred_nn, z)
        else:
            true_struct = two_peak_separation(tgt_np, z)
            pred_struct = two_peak_separation(pred_nn, z)

        nn_struct_err = np.nan if np.isnan(true_struct) or np.isnan(pred_struct) else abs(pred_struct - true_struct)

        metrics["profile_nrmse"][(group, "1D dilated resnet")].append(nn_profile_err)
        metrics["spectral_error"][(group, "1D dilated resnet")].append(nn_spec_err)
        metrics["structure_error"][(group, "1D dilated resnet")].append(nn_struct_err)

        # ---------- GS (multi-seed, same interface as your Cell 10) ----------
        rho_true = torch.tensor(tgt_np, dtype=torch.float32, device=device)
        I_meas, _ = forward_spectrum_fft(rho_true)
        I_meas = I_meas.real
        I_meas = I_meas / torch.clamp(torch.max(I_meas), min=1e-12)

        support_mask = make_support_mask(N, dx_um, support_width_um, device) if use_support else None

        gs_profile_errs_this_sample = []
        gs_spec_errs_this_sample = []
        gs_struct_errs_this_sample = []

        for seed in gs_seeds:
            torch.manual_seed(seed)

            rho_gs = gerchberg_saxton_1d_torch(
                I_meas=I_meas,
                n_iters=gs_iters,
                support_mask=support_mask,
                smooth=True,
                device=device,
            )

            rho_gs = normalize_profile(rho_gs.detach().cpu().numpy())
            rho_gs = align_to_true_center(rho_gs, tgt_np, z, dx_um)

            gs_profile_err = profile_nrmse(rho_gs, tgt_np)
            gs_spec_err = band_spectral_error(rho_gs, img.squeeze().cpu().numpy())

            if group == "Single":
                gs_struct = fwhm_width(rho_gs, z)
            else:
                gs_struct = two_peak_separation(rho_gs, z)

            gs_struct_err = np.nan if np.isnan(true_struct) or np.isnan(gs_struct) else abs(gs_struct - true_struct)

            gs_profile_errs_this_sample.append(gs_profile_err)
            gs_spec_errs_this_sample.append(gs_spec_err)
            gs_struct_errs_this_sample.append(gs_struct_err)

        # use per-sample median GS performance for fair aggregate comparison
        metrics["profile_nrmse"][(group, "GS")].append(np.nanmedian(gs_profile_errs_this_sample))
        metrics["spectral_error"][(group, "GS")].append(np.nanmedian(gs_spec_errs_this_sample))
        metrics["structure_error"][(group, "GS")].append(np.nanmedian(gs_struct_errs_this_sample))

        # store within-sample GS seed spread (procedural variability)
        gs_seed_spread[group].append(np.nanstd(gs_profile_errs_this_sample))

# -----------------------------
# Plotting helpers
# -----------------------------
group_order = ["Single", "Double"]
method_order = ["1D dilated resnet", "GS"]
colors = {
    "1D dilated resnet": "#E68613",
    "GS": "#4C78A8",
}

def grouped_boxplot(ax, metric_dict, ylabel, title, xticklabels, show_legend=False):
    positions = []
    data = []
    facecolors = []

    base_positions = np.arange(len(group_order)) * 3.0
    offsets = [-0.45, 0.45]

    for gi, group in enumerate(group_order):
        for mi, method in enumerate(method_order):
            vals = np.array(metric_dict[(group, method)], dtype=float)
            vals = vals[np.isfinite(vals)]
            positions.append(base_positions[gi] + offsets[mi])
            data.append(vals)
            facecolors.append(colors[method])

    bp = ax.boxplot(
        data,
        positions=positions,
        widths=0.75,
        patch_artist=True,
        showfliers=False,
        medianprops=dict(color="black", linewidth=1.8),
        whiskerprops=dict(linewidth=1.4),
        capprops=dict(linewidth=1.4),
        boxprops=dict(linewidth=1.4),
    )

    for patch, fc in zip(bp["boxes"], facecolors):
        patch.set_facecolor(fc)
        patch.set_alpha(0.60)

    ax.set_xticks(base_positions)
    ax.set_xticklabels(xticklabels)
    ax.set_ylabel(ylabel)
    ax.set_title(title)
    ax.grid(axis="y", linestyle="--", alpha=0.25)

    if show_legend:
        from matplotlib.patches import Patch
        handles = [Patch(facecolor=colors[m], edgecolor="black", alpha=0.60, label=m) for m in method_order]
        ax.legend(handles=handles, frameon=False)

# -----------------------------
# Figure
# -----------------------------
fig, axes = plt.subplots(2, 2, figsize=(13.5, 9.5))
fig.suptitle(
    "Validation-set quantitative comparison: 1D dilated resnet vs GS\n(single- and double-bunch cases only)",
    fontsize=15
)

# (a) profile NRMSE
grouped_boxplot(
    axes[0, 0],
    metrics["profile_nrmse"],
    ylabel="Profile NRMSE",
    title="(a) Profile reconstruction error",
    xticklabels=["Single", "Double"],
    show_legend=True,
)

# (b) spectral error
grouped_boxplot(
    axes[0, 1],
    metrics["spectral_error"],
    ylabel="Band-limited spectral mismatch",
    title="(b) Spectral consistency error",
    xticklabels=["Single", "Double"],
)

# (c) structure-aware error
# Here: single -> FWHM error, double -> peak-separation error
grouped_boxplot(
    axes[1, 0],
    metrics["structure_error"],
    ylabel="Single: |ΔFWHM|   /   Double: |Δseparation| (μm)",
    title="(c) Structure-aware error",
    xticklabels=["Single (FWHM)", "Double (peak sep.)"],
)

# (d) GS seed spread
spread_data = [
    np.array(gs_seed_spread["Single"], dtype=float),
    np.array(gs_seed_spread["Double"], dtype=float),
]
spread_positions = [0, 3]

bp = axes[1, 1].boxplot(
    spread_data,
    positions=spread_positions,
    widths=0.9,
    patch_artist=True,
    showfliers=False,
    medianprops=dict(color="black", linewidth=1.8),
    whiskerprops=dict(linewidth=1.4),
    capprops=dict(linewidth=1.4),
    boxprops=dict(linewidth=1.4),
)
for patch in bp["boxes"]:
    patch.set_facecolor(colors["GS"])
    patch.set_alpha(0.60)

# deterministic baseline line for 1D dilated resnet
axes[1, 1].axhline(0.0, color=colors["1D dilated resnet"], linestyle="--", linewidth=2.0, label="1D dilated resnet (deterministic)")
axes[1, 1].set_xticks(spread_positions)
axes[1, 1].set_xticklabels(["Single", "Double"])
axes[1, 1].set_ylabel("Std. of GS profile NRMSE across seeds")
axes[1, 1].set_title("(d) GS procedural variability")
axes[1, 1].grid(axis="y", linestyle="--", alpha=0.25)
axes[1, 1].legend(frameon=False)

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# -----------------------------
# Console summary (median values)
# -----------------------------
print("\nMedian summary over selected validation samples")
print("------------------------------------------------")
for metric_name, metric_dict in metrics.items():
    print(f"\n[{metric_name}]")
    for group in group_order:
        for method in method_order:
            vals = np.array(metric_dict[(group, method)], dtype=float)
            vals = vals[np.isfinite(vals)]
            if len(vals) == 0:
                print(f"{group:>6s} | {method:>18s} : n=0")
            else:
                print(f"{group:>6s} | {method:>18s} : median={np.median(vals):.4f}, IQR=({np.percentile(vals,25):.4f}, {np.percentile(vals,75):.4f}), n={len(vals)}")
# Out:
# Selected validation samples:
#   Single: 500
#   Double: 500
# C:\Users\23697\AppData\Local\Temp\ipykernel_9524\2253919190.py:262: RuntimeWarning: All-NaN slice encountered
#   metrics["structure_error"][(group, "GS")].append(np.nanmedian(gs_struct_errs_this_sample))
# Median summary over selected validation samples
# ------------------------------------------------
#
# [profile_nrmse]
# Single |  1D dilated resnet : median=0.1057, IQR=(0.0711, 0.1620), n=500
# Single |                 GS : median=0.1246, IQR=(0.0708, 0.1957), n=500
# Double |  1D dilated resnet : median=0.1680, IQR=(0.1184, 0.2466), n=500
# Double |                 GS : median=0.2979, IQR=(0.1992, 0.5603), n=500
#
# [spectral_error]
# Single |  1D dilated resnet : median=0.0616, IQR=(0.0414, 0.1104), n=500
# Single |                 GS : median=0.0418, IQR=(0.0279, 0.0776), n=500
# Double |  1D dilated resnet : median=0.0928, IQR=(0.0631, 0.1597), n=500
# ...

# %%
import importlib
import src.quant_eval_plots as qep
qep = importlib.reload(qep)

print(qep.__file__)
print(hasattr(qep, "build_quantitative_cache"))
# Out:
# d:\23697\Desktop\Dilated_ResNet_phase_retrieval\src\quant_eval_plots.py
# True

# %%
# Cell X0: build quantitative cache once (single + double, 500 per group)

comparison_cache = qep.build_quantitative_cache(
    model=model,
    val_dataset=val_dataset,
    tgt_files=tgt_files,
    target_folder=target_folder,
    device=device,
    dx_um=dx_um,
    f_min=f_min,
    f_max=f_max,
    f_display_max=f_display_max,
    pad_factor=pad_factor,
    compute_form_factor=compute_form_factor,
    k_to_THz=k_to_THz,
    forward_spectrum_fft=forward_spectrum_fft,
    gerchberg_saxton_1d_torch=gerchberg_saxton_1d_torch,
    fwhm_center=fwhm_center,
    align_by_fwhm=align_by_fwhm,
    max_per_group=30,
    gs_seeds=(0, 1, 2),
    gs_iters=2000,
    use_support=True,
    support_width_um=30.0,
    vis_indices=(101, 102, 103),
    model_name="1D dilated resnet",
)

qep.print_cache_summary(comparison_cache)
# Out:
# Selected validation samples
#   Single: 30
#   Double: 30
#
# Timing summary
# --------------
#  1D dilated resnet: 1.07 ± 0.17 ms  (n=60)
#                 GS: 490.94 ± 11.62 ms  (n=60)
#
# Metric summary (median [Q1, Q3])
# ---------------------------------
#
# [profile_nrmse]
# Single |  1D dilated resnet : 0.1003 [0.0654, 0.1471]  n=30
# Single |                 GS : 0.1296 [0.0642, 0.2188]  n=30
# Double |  1D dilated resnet : 0.1595 [0.1141, 0.2320]  n=30
# Double |                 GS : 0.3682 [0.2439, 0.5582]  n=30
#
# [spectral_error]
# Single |  1D dilated resnet : 0.0660 [0.0552, 0.0904]  n=30
# Single |                 GS : 0.0422 [0.0223, 0.0638]  n=30
# Double |  1D dilated resnet : 0.0806 [0.0620, 0.1264]  n=30
# Double |                 GS : 0.1616 [0.0569, 0.4743]  n=30
#
# [structure_error]
# Single |  1D dilated resnet : 0.1500 [0.0000, 0.1500]  n=30
# Single |                 GS : 0.1500 [0.0000, 0.1500]  n=30
# ...

# %%
fig, axes = qep.plot_representative_examples(comparison_cache, figsize=(8.5, 10.5))
plt.show()

fig, ax = qep.plot_panel_a(comparison_cache, figsize=(7.2, 5.1))
plt.show()

fig, axes = qep.plot_panel_bc_double(comparison_cache, figsize=(11.0, 4.8))
plt.show()

fig, ax = qep.plot_panel_d(comparison_cache, figsize=(7.2, 5.1))
plt.show()

# %%
# Cell 11: BubbleWrap preprocessing only

folder = "./app/form factor/bubble wrap"
target_points = 256

file_order = [
    "F1.csv", "F2.csv", "F3.csv",
    "rho1.csv", "rho2.csv", "rho3.csv"
]

F_list = []
rho_list = []

resample = resample_linear

for filename in file_order:
    path = os.path.join(folder, filename)
    data = pd.read_csv(path)

    x = data.iloc[:, 0].values.astype(float)
    y = data.iloc[:, 1].values.astype(float)

    if filename.startswith("F"):
        omega = x * 1e14
        freq_THz = omega / (2 * np.pi) / 1e12

        mask = (freq_THz >= 50) & (freq_THz <= 230)
        freq_crop = freq_THz[mask]
        y_crop = y[mask]

        y_crop = y_crop / np.max(np.abs(y_crop))
        _, y_res = resample(freq_crop, y_crop, target_points)

        F_list.append(y_res.copy())

    else:
        index_coord = x / dx_um
        index_coord = np.round(index_coord).astype(int)

        sort_idx = np.argsort(index_coord)
        index_coord = index_coord[sort_idx]
        y_sorted = y[sort_idx]

        idx_min = index_coord.min()
        idx_max = index_coord.max()

        full_index = np.arange(idx_min, idx_max + 1)
        full_rho = np.zeros_like(full_index, dtype=float)
        full_rho[index_coord - idx_min] = y_sorted

        full_rho = full_rho / np.max(np.abs(full_rho))

        current_len = len(full_rho)
        if current_len > target_points:
            start = (current_len - target_points) // 2
            full_rho = full_rho[start:start + target_points]
        else:
            pad_total = target_points - current_len
            pad_left = pad_total // 2
            pad_right = pad_total - pad_left
            full_rho = np.pad(full_rho, (pad_left, pad_right))

        rho_list.append(full_rho.copy())

print("Loaded BubbleWrap data:")
# print("len(F_list)   =", len(F_list))
# print("len(rho_list) =", len(rho_list))
# print("F shape       =", np.array(F_list).shape)
# print("rho shape     =", np.array(rho_list).shape)
# Out:
# Loaded BubbleWrap data:
# len(F_list)   = 3
# len(rho_list) = 3
# F shape       = (3, 256)
# rho shape     = (3, 256)

# %%
# Cell 12: BubbleWrap → CNN Reconstruction

model.eval()

fig, axes = plt.subplots(2, 3, figsize=(15, 8))
fig.suptitle("BubbleWrap → CNN Reconstruction", fontsize=15)

titles = ["Profile 1", "Profile 2", "Profile 3"]

for col in range(3):

    F_np = F_list[col]
    rho_np = rho_list[col]

    # 转成 tensor 输入模型
    img = torch.tensor(F_np * F_np, dtype=torch.float32).unsqueeze(0).to(device)
    tgt = rho_np  # numpy

    # forward
    with torch.no_grad():
        pred = model(img).squeeze().cpu().numpy()

    # ================= TOP ROW: profile =================
    N = len(tgt)
    z = np.arange(N) * dx_um

    ax_top = axes[0, col]
    ax_top.plot(z, tgt, linewidth=2, label="BubbleWrap")
    ax_top.plot(z, pred, '--', linewidth=2, color='orange', label="CNN Reconstruction")
    ax_top.set_xlabel("z (μm)")
    ax_top.set_ylabel("Normalized charge")
    ax_top.set_title(titles[col])
    ax_top.grid(True)
    ax_top.legend()

    # ================= BOTTOM ROW: spectrum =================
    k_rec, F2_rec = compute_form_factor(z, pred, pad_factor=pad_factor)
    freq_rec = k_to_THz(k_rec)

    mask_full = (freq_rec >= 0) & (freq_rec <= f_display_max)
    freq_full = freq_rec[mask_full]
    F2_full = F2_rec[mask_full]

    spectrum_measured = F_np * F_np
    freq_meas = np.linspace(f_min, f_max, len(spectrum_measured))

    mask_band_full = (freq_full >= f_min) & (freq_full <= f_max)
    if np.any(mask_band_full):
        scale_forward = np.max(F2_full[mask_band_full])
    else:
        scale_forward = np.max(F2_full)

    scale_measured = np.max(spectrum_measured)

    scale_forward = scale_forward if scale_forward > 0 else 1.0
    scale_measured = scale_measured if scale_measured > 0 else 1.0

    ax_bottom = axes[1, col]

    ax_bottom.axvspan(0, f_min, color='blue', alpha=0.08)
    ax_bottom.axvspan(f_max, f_display_max, color='blue', alpha=0.08)

    ax_bottom.plot(
        freq_full,
        F2_full / scale_forward,
        '--',
        linewidth=2,
        color='orange',
        label="Forward (CNN)"
    )

    ax_bottom.plot(
        freq_meas,
        spectrum_measured / scale_measured,
        linewidth=2,
        label="Measured spectrum"
    )

    ax_bottom.set_xlim(0, f_display_max)
    ax_bottom.set_xlabel("Frequency (THz)")
    ax_bottom.set_ylabel("Normalized |F|² (band-max)")
    ax_bottom.set_title("Spectral Consistency")
    ax_bottom.grid(True)
    ax_bottom.legend()

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
