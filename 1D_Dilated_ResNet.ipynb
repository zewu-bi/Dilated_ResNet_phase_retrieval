# %%
# Cell 1: imports

import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
from torch.utils.data import DataLoader, random_split
from torch.utils.tensorboard import SummaryWriter
from torch.serialization import add_safe_globals

from src.dilated_resnet import (
    CTRDataset,
    DilatedResBlock,
    Dilated_CNN_ResNet,
    AsinhMSEWithPhysicsLoss,
    train_one_epoch,
    evaluate,
)
from src.form_factor_utils import (
    l1_nonneg_normalize,
    compute_form_factor,
    k_to_THz,
)
from src.reconstruction_utils import (
    fwhm_center,
    align_by_fwhm,
    weighted_error,
    gerchberg_saxton_1d_torch,
    forward_spectrum_fft,
    resample_linear,
)

# %%
# Cell 2: basic config

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# Cell 3: paths, hyperparameters, and shared settings

img_folder    = "./dataset/G1_G2/img"
target_folder = "./dataset/G1_G2/target"

num_exp = 40
sequence_length = 256
batch_size = 256
num_epochs = 200
learning_rate = 1e-3
val_ratio = 0.2
split_seed = 42

# shared plotting / physics settings
dx_um = 0.15
f_min = 50
f_max = 230
f_display_max = 250
pad_factor = 10

# %%
# Cell 4: dataset + fixed train/val split + dataloaders

img_files = sorted([f for f in os.listdir(img_folder) if f.endswith(".pt")])
tgt_files = sorted([f for f in os.listdir(target_folder) if f.endswith(".pt")])

# print("Number of img files   :", len(img_files))
# print("Number of target files:", len(tgt_files))

full_dataset = CTRDataset(img_folder, target_folder, img_files, tgt_files, seq_len=sequence_length)
print("Total samples in dataset:", len(full_dataset))

num_total = len(full_dataset)
num_val = int(num_total * val_ratio)
num_train = num_total - num_val

split_generator = torch.Generator().manual_seed(split_seed)
train_dataset, val_dataset = random_split(
    full_dataset,
    [num_train, num_val],
    generator=split_generator,
)

print(f"Train samples: {num_train}, Val samples: {num_val}")
# print("First 5 val indices:", val_dataset.indices[:5])

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Total samples in dataset: 90000
# Train samples: 72000, Val samples: 18000

# %%
# Cell 5: model + loss + optimizer + train/eval loops

model = Dilated_CNN_ResNet(in_ch=1, base_ch=64).to(device)
criterion = AsinhMSEWithPhysicsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
# Cell 6: train and save checkpoints

writer = SummaryWriter(log_dir="./logs/exp{}".format(num_exp))
train_losses = []
val_losses = []

for epoch in range(1, num_epochs + 1):
    train_loss = train_one_epoch(model, train_loader, optimizer, criterion, device)
    val_loss = evaluate(model, val_loader, criterion, device)

    train_losses.append(train_loss)
    val_losses.append(val_loss)

    writer.add_scalar("Loss/train", train_loss, epoch)
    writer.add_scalar("Loss/val", val_loss, epoch)

    print(f"Epoch [{epoch:03d}/{num_epochs}] Train Loss: {train_loss:.6f}  |  Val Loss: {val_loss:.6f}")

    os.makedirs("./model/exp{}".format(num_exp), exist_ok=True)
    torch.save(model, "./model/exp{}/Dilated_ResNet_{}.pth".format(num_exp, epoch))

writer.close()
print("Training finished. Logs saved to ./logs/exp{}".format(num_exp))
# Out:
# Epoch [001/200] Train Loss: 0.029697  |  Val Loss: 0.017578
# Epoch [002/200] Train Loss: 0.012981  |  Val Loss: 0.010712
# Epoch [003/200] Train Loss: 0.009476  |  Val Loss: 0.008855
# Epoch [004/200] Train Loss: 0.008439  |  Val Loss: 0.008105
# Epoch [005/200] Train Loss: 0.007687  |  Val Loss: 0.007365
# Epoch [006/200] Train Loss: 0.007233  |  Val Loss: 0.007023
# Epoch [007/200] Train Loss: 0.006965  |  Val Loss: 0.006636
# Epoch [008/200] Train Loss: 0.006532  |  Val Loss: 0.006390
# Epoch [009/200] Train Loss: 0.006274  |  Val Loss: 0.006221
# Epoch [010/200] Train Loss: 0.006056  |  Val Loss: 0.006031
# Epoch [011/200] Train Loss: 0.005913  |  Val Loss: 0.006060
# Epoch [012/200] Train Loss: 0.005724  |  Val Loss: 0.005771
# Epoch [013/200] Train Loss: 0.005498  |  Val Loss: 0.005505
# Epoch [014/200] Train Loss: 0.005355  |  Val Loss: 0.005708
# Epoch [015/200] Train Loss: 0.005281  |  Val Loss: 0.004993
# Epoch [016/200] Train Loss: 0.005049  |  Val Loss: 0.005893
# ...

# %%
# Cell 7: load model

add_safe_globals([DilatedResBlock, Dilated_CNN_ResNet])

model_path = "./model/exp{}/Dilated_ResNet_{}.pth".format(num_exp, num_epochs)
print("Loading model:", model_path)

model = torch.load(model_path, map_location=device, weights_only=False)
# Out:
# Loading model: ./model/exp40/Dilated_ResNet_200.pth

# %%
# Cell 8: validation visualization (merged, keep only the 3x2 figure)

model.eval()

vis_indices = [100, 101, 102]

fig, axes = plt.subplots(3, 2, figsize=(13, 11))
fig.suptitle("Validation Set: Multi-Gaussian Reconstruction under Finite Bandwidth", fontsize=15)

for row, idx in enumerate(vis_indices):
    img, tgt = val_dataset[idx]
    img = img.unsqueeze(0).to(device)
    tgt = l1_nonneg_normalize(tgt.squeeze().cpu().numpy())

    with torch.no_grad():
        pred = model(img).squeeze().cpu().numpy()
    pred = l1_nonneg_normalize(pred)

    z = np.arange(len(tgt)) * dx_um

    ax_left = axes[row, 0]
    ax_left.plot(z, tgt, linewidth=2, label="True")
    ax_left.plot(z, pred, "--", linewidth=2, color="orange", label="Reconstruction")
    ax_left.set_xlabel("z (μm)")
    ax_left.set_ylabel("Normalized charge")
    ax_left.set_title(f"Validation Sample {idx}")
    ax_left.grid(True)
    ax_left.legend()

    k_rec, F2_rec = compute_form_factor(z, pred, pad_factor=pad_factor)
    freq_rec = k_to_THz(k_rec)

    mask_full = (freq_rec >= 0) & (freq_rec <= f_display_max)
    freq_full = freq_rec[mask_full]
    F2_full = F2_rec[mask_full]

    spectrum_measured = img.squeeze().cpu().numpy()
    freq_meas = np.linspace(f_min, f_max, len(spectrum_measured))

    mask_band_full = (freq_full >= f_min) & (freq_full <= f_max)
    scale_forward = np.max(F2_full[mask_band_full]) if np.any(mask_band_full) else np.max(F2_full)
    scale_measured = np.max(spectrum_measured)

    scale_forward = scale_forward if scale_forward > 0 else 1.0
    scale_measured = scale_measured if scale_measured > 0 else 1.0

    ax_right = axes[row, 1]
    ax_right.axvspan(0, f_min, color="blue", alpha=0.08)
    ax_right.axvspan(f_max, f_display_max, color="blue", alpha=0.08)
    ax_right.plot(freq_meas, spectrum_measured / scale_measured, linewidth=2, label="True")
    ax_right.plot(freq_full, F2_full / scale_forward, "--", linewidth=2, color="orange", label="Reconstruction")
    ax_right.set_xlim(0, f_display_max)
    ax_right.set_xlabel("Frequency (THz)")
    ax_right.set_ylabel("Normalized |F|² (band-max)")
    ax_right.set_title("Spectral Consistency")
    ax_right.grid(True)
    ax_right.legend()

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
# Cell 9: BubbleWrap preprocessing only

folder = "./app/form factor/bubble wrap"
target_points = 256

file_order = [
    "F1.csv", "F2.csv", "F3.csv",
    "rho1.csv", "rho2.csv", "rho3.csv"
]

F_list = []
rho_list = []

resample = resample_linear

for filename in file_order:
    path = os.path.join(folder, filename)
    data = pd.read_csv(path)

    x = data.iloc[:, 0].values.astype(float)
    y = data.iloc[:, 1].values.astype(float)

    if filename.startswith("F"):
        omega = x * 1e14
        freq_THz = omega / (2 * np.pi) / 1e12

        mask = (freq_THz >= 50) & (freq_THz <= 230)
        freq_crop = freq_THz[mask]
        y_crop = y[mask]

        y_crop = y_crop / np.max(np.abs(y_crop))
        _, y_res = resample(freq_crop, y_crop, target_points)

        F_list.append(y_res.copy())

    else:
        index_coord = x / dx_um
        index_coord = np.round(index_coord).astype(int)

        sort_idx = np.argsort(index_coord)
        index_coord = index_coord[sort_idx]
        y_sorted = y[sort_idx]

        idx_min = index_coord.min()
        idx_max = index_coord.max()

        full_index = np.arange(idx_min, idx_max + 1)
        full_rho = np.zeros_like(full_index, dtype=float)
        full_rho[index_coord - idx_min] = y_sorted

        full_rho = full_rho / np.max(np.abs(full_rho))

        current_len = len(full_rho)
        if current_len > target_points:
            start = (current_len - target_points) // 2
            full_rho = full_rho[start:start + target_points]
        else:
            pad_total = target_points - current_len
            pad_left = pad_total // 2
            pad_right = pad_total - pad_left
            full_rho = np.pad(full_rho, (pad_left, pad_right))

        rho_list.append(full_rho.copy())

print("Loaded BubbleWrap data:")
# print("len(F_list)   =", len(F_list))
# print("len(rho_list) =", len(rho_list))
# print("F shape       =", np.array(F_list).shape)
# print("rho shape     =", np.array(rho_list).shape)
# Out:
# Loaded BubbleWrap data:

# %%
# Cell 10: BubbleWrap → CNN Reconstruction

model.eval()

fig, axes = plt.subplots(2, 3, figsize=(15, 8))
fig.suptitle("BubbleWrap → CNN Reconstruction", fontsize=15)

titles = ["Profile 1", "Profile 2", "Profile 3"]

for col in range(3):

    F_np = F_list[col]
    rho_np = rho_list[col]

    # 转成 tensor 输入模型
    img = torch.tensor(F_np * F_np, dtype=torch.float32).unsqueeze(0).to(device)
    tgt = rho_np  # numpy

    # forward
    with torch.no_grad():
        pred = model(img).squeeze().cpu().numpy()

    # ================= TOP ROW: profile =================
    N = len(tgt)
    z = np.arange(N) * dx_um

    ax_top = axes[0, col]
    ax_top.plot(z, tgt, linewidth=2, label="BubbleWrap")
    ax_top.plot(z, pred, '--', linewidth=2, color='orange', label="CNN Reconstruction")
    ax_top.set_xlabel("z (μm)")
    ax_top.set_ylabel("Normalized charge")
    ax_top.set_title(titles[col])
    ax_top.grid(True)
    ax_top.legend()

    # ================= BOTTOM ROW: spectrum =================
    k_rec, F2_rec = compute_form_factor(z, pred, pad_factor=pad_factor)
    freq_rec = k_to_THz(k_rec)

    mask_full = (freq_rec >= 0) & (freq_rec <= f_display_max)
    freq_full = freq_rec[mask_full]
    F2_full = F2_rec[mask_full]

    spectrum_measured = F_np * F_np
    freq_meas = np.linspace(f_min, f_max, len(spectrum_measured))

    mask_band_full = (freq_full >= f_min) & (freq_full <= f_max)
    if np.any(mask_band_full):
        scale_forward = np.max(F2_full[mask_band_full])
    else:
        scale_forward = np.max(F2_full)

    scale_measured = np.max(spectrum_measured)

    scale_forward = scale_forward if scale_forward > 0 else 1.0
    scale_measured = scale_measured if scale_measured > 0 else 1.0

    ax_bottom = axes[1, col]

    ax_bottom.axvspan(0, f_min, color='blue', alpha=0.08)
    ax_bottom.axvspan(f_max, f_display_max, color='blue', alpha=0.08)

    ax_bottom.plot(
        freq_full,
        F2_full / scale_forward,
        '--',
        linewidth=2,
        color='orange',
        label="Forward (CNN)"
    )

    ax_bottom.plot(
        freq_meas,
        spectrum_measured / scale_measured,
        linewidth=2,
        label="Measured spectrum"
    )

    ax_bottom.set_xlim(0, f_display_max)
    ax_bottom.set_xlabel("Frequency (THz)")
    ax_bottom.set_ylabel("Normalized |F|² (band-max)")
    ax_bottom.set_title("Spectral Consistency")
    ax_bottom.grid(True)
    ax_bottom.legend()

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
import importlib
import src.prab_plot_style as prab_style
import src.quant_eval_plots as qep

prab_style = importlib.reload(prab_style)
qep = importlib.reload(qep)

print(qep.__file__)

comparison_cache = qep.build_quantitative_cache(
    model=model,
    val_dataset=val_dataset,
    tgt_files=tgt_files,
    target_folder=target_folder,
    device=device,
    dx_um=dx_um,
    f_min=f_min,
    f_max=f_max,
    f_display_max=f_display_max,
    pad_factor=pad_factor,
    compute_form_factor=compute_form_factor,
    k_to_THz=k_to_THz,
    forward_spectrum_fft=forward_spectrum_fft,
    gerchberg_saxton_1d_torch=gerchberg_saxton_1d_torch,
    fwhm_center=fwhm_center,
    align_by_fwhm=align_by_fwhm,
    n_random_samples=1000,
    sample_seed=0,
    gs_seeds=(0, 1, 2),          # metrics still use 3-seed median, not best-of
    gs_iters=2000,
    use_support=True,
    support_width_um=30.0,
    vis_indices=(100,),          # only this example is visualized
    dense_vis_seed_count=100,    # only this example uses 100 GS seeds for envelope
    model_name="1D dilated resnet",
)

qep.print_cache_summary(comparison_cache)
# Out:
# d:\23697\Desktop\Dilated_ResNet_phase_retrieval\src\quant_eval_plots.py
# Selected validation samples
#   total: 1000
#   forced vis indices in cache: (100,)
#   Single: 122
#   Double: 878
#
# Timing summary
# --------------
#  1D dilated resnet: 2.53 ± 11.81 ms  (n=1000)
#                 GS: 945.66 ± 109.81 ms  (n=1000)
#
# Metric summary (median [Q1, Q3])
# ---------------------------------
#
# [profile_nrmse]
# Single |  1D dilated resnet : 0.1041 [0.0718, 0.1508]  n=122
# Single |                 GS : 0.1039 [0.0579, 0.1785]  n=122
# Double |  1D dilated resnet : 0.1612 [0.1137, 0.2465]  n=878
# Double |                 GS : 0.3787 [0.2459, 0.5942]  n=878
#
# [spectral_error]
# Single |  1D dilated resnet : 0.0616 [0.0389, 0.0996]  n=122
# Single |                 GS : 0.0421 [0.0261, 0.0698]  n=122
# Double |  1D dilated resnet : 0.0880 [0.0586, 0.1606]  n=878
# Double |                 GS : 0.1776 [0.0782, 0.4114]  n=878
#
# [structure_error]
# ...

# %%
fig, ax = qep.plot_representative_examples(
    comparison_cache,
    example_idx=100,
    figsize=(7.2, 4.6),
)
plt.show()

fig, ax = qep.plot_panel_a(comparison_cache, figsize=(7.2, 5.1))
plt.show()

fig, axes = qep.plot_panel_bc_double(comparison_cache, figsize=(8.8, 5.0))
plt.show()

fig, ax = qep.plot_double_advantage_heatmap(
    comparison_cache,
    figsize=(7.6, 5.6),
    x_bins=10,
    y_bins=10,
    min_count_per_bin=3,
    x_range=(10.0, 20.0),
    y_range=(1.0, 5.0),
)
plt.show()

# %%
# Cell 9: Noise robustness of NN and GS w.r.t. zero-noise reconstruction baseline

import importlib
import src.prab_plot_style as prab_style
prab_style = importlib.reload(prab_style)
prab_style.setup_prab_style()

# =========================
# user-configurable settings
# =========================
rand_idx = 102                      # choose any validation index here
rep_levels = [1e-4, 1e-3, 1e-2]     # three representative noise levels
noise_levels = np.logspace(-4, -2, 15)
n_trials = 50

legend_loc = "upper right"
enforce_monotone_display = False     # set False if you want raw statistics

# GS settings
gs_seed_fixed = 0                   # fix GS seed: only measurement noise varies
gs_iters_local = 2000
use_support_local = True
support_width_um_local = 30.0

# figure texts: CNN
cnn_left_title = "1D dilated ResNet reconstruction under spectral noise"
cnn_right_title = "1D dilated ResNet: deviation from zero-noise reconstruction"
cnn_left_ylabel = "Normalized charge"
cnn_right_ylabel = "Peak-weighted relative error to zero-noise output"
cnn_caption = "(CNN) Black solid line: zero-noise reconstruction. Colored dashed lines: representative noisy reconstructions."

# figure texts: GS
gs_left_title = "GS reconstruction under spectral noise"
gs_right_title = "GS: deviation from zero-noise reconstruction"
gs_left_ylabel = "Normalized charge"
gs_right_ylabel = "Peak-weighted relative error to zero-noise output"
gs_caption = "(GS) Black solid line: zero-noise reconstruction. Colored dashed lines: representative noisy reconstructions."

xlabel_profile = "z (μm)"
xlabel_noise = "Noise level"

# colors / linestyles
baseline_color = "black"
rep_colors = ["#1f77b4", "#e67e22", "#d62728"]
rep_linestyles = ["--", "-.", ":"]
box_fill_nn = "#e67e22"
box_fill_gs = "#2ca02c"
box_alpha = 0.45
median_color = "black"


# =========================
# helpers
# =========================
def set_torch_seed(seed: int):
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)


def normalize_profile(y):
    y = np.asarray(y, dtype=float)
    y = np.clip(y, 0.0, None)
    s = y.sum()
    if s <= 0:
        return np.zeros_like(y)
    return y / s


def weighted_error(pred, ref, weight):
    pred = np.asarray(pred, dtype=float)
    ref = np.asarray(ref, dtype=float)
    weight = np.asarray(weight, dtype=float)

    num = np.sqrt(np.sum(weight * (pred - ref) ** 2))
    den = np.sqrt(np.sum(weight * ref ** 2))
    return num / den if den > 0 else np.nan


def maybe_align(pred, z, c_ref, dx_um):
    try:
        return np.asarray(align_by_fwhm(pred, z, c_ref, dx_um), dtype=float)
    except Exception:
        return np.asarray(pred, dtype=float)


def make_support_mask_local(N, dx_um, width_um, device):
    z_centered = (np.arange(N) - N // 2) * dx_um
    mask_np = (np.abs(z_centered) <= width_um / 2).astype(np.float32)
    return torch.tensor(mask_np, dtype=torch.float32, device=device)


def reconstruct_nn_from_band(img_band):
    with torch.no_grad():
        pred = model(img_band).squeeze().detach().cpu().numpy()
    return normalize_profile(pred)


def reconstruct_gs_from_true_profile(tgt_profile, nl, noise_seed, gs_seed):
    rho_true = torch.tensor(tgt_profile, dtype=torch.float32, device=device)

    # measured spectrum for GS
    I_meas, _ = forward_spectrum_fft(rho_true)
    I_meas = I_meas.real
    I_meas = I_meas / torch.clamp(torch.max(I_meas), min=1e-12)

    # add measurement noise
    set_torch_seed(noise_seed)
    noise = nl * torch.randn_like(I_meas)
    I_noisy = torch.clamp(I_meas + noise, min=0.0)
    I_noisy = I_noisy / torch.clamp(torch.max(I_noisy), min=1e-12)

    support_mask = None
    if use_support_local:
        support_mask = make_support_mask_local(len(tgt_profile), dx_um, support_width_um_local, device)

    # fix GS seed so only measurement noise changes
    set_torch_seed(gs_seed)
    rho_gs = gerchberg_saxton_1d_torch(
        I_meas=I_noisy,
        n_iters=gs_iters_local,
        support_mask=support_mask,
        smooth=True,
        device=device,
    )
    rho_gs = rho_gs.detach().cpu().numpy()
    return normalize_profile(rho_gs)


def monotone_curves_by_trial(error_curves_2d):
    # shape: [n_noise_levels_total, n_trials]
    arr = np.asarray(error_curves_2d, dtype=float).copy()
    # enforce nondecreasing behavior along noise axis for each trial
    for j in range(arr.shape[1]):
        arr[:, j] = np.maximum.accumulate(arr[:, j])
    return arr


# =========================
# load chosen sample
# =========================
model.eval()

img, tgt = val_dataset[rand_idx]
img = img.unsqueeze(0).to(device)
tgt = tgt.squeeze().cpu().numpy()

N = len(tgt)
z = np.arange(N) * dx_um

tgt_norm = normalize_profile(tgt)

# =========================
# zero-noise baselines
# =========================
# CNN baseline
cnn_base = reconstruct_nn_from_band(img)
cnn_base_max = cnn_base / max(np.max(cnn_base), 1e-12)
cnn_c_ref = fwhm_center(cnn_base_max, z)

# GS baseline
gs_base = reconstruct_gs_from_true_profile(tgt_norm, nl=0.0, noise_seed=0, gs_seed=gs_seed_fixed)
gs_base_max = gs_base / max(np.max(gs_base), 1e-12)
gs_c_ref = fwhm_center(gs_base_max, z)

# weights now follow the zero-noise reconstructions
cnn_weight = cnn_base / max(np.max(cnn_base), 1e-12)
gs_weight = gs_base / max(np.max(gs_base), 1e-12)

# =========================
# representative curves
# =========================
cnn_rep_profiles = []
gs_rep_profiles = []

for nl in rep_levels:
    # CNN representative
    set_torch_seed(0)
    noise = nl * torch.randn_like(img)
    img_noisy = torch.clamp(img + noise, min=0.0)
    pred_nn = reconstruct_nn_from_band(img_noisy)
    pred_nn = maybe_align(pred_nn, z, cnn_c_ref, dx_um)
    cnn_rep_profiles.append((nl, pred_nn))

    # GS representative
    pred_gs = reconstruct_gs_from_true_profile(
        tgt_profile=tgt_norm,
        nl=nl,
        noise_seed=0,
        gs_seed=gs_seed_fixed,
    )
    pred_gs = maybe_align(pred_gs, z, gs_c_ref, dx_um)
    gs_rep_profiles.append((nl, pred_gs))

# align baselines to themselves for consistency
cnn_base_aligned = maybe_align(cnn_base, z, cnn_c_ref, dx_um)
gs_base_aligned = maybe_align(gs_base, z, gs_c_ref, dx_um)

# =========================
# statistical scan: CNN
# =========================
noise_levels_all = np.concatenate([[0.0], noise_levels])
cnn_all_errors = []

for nl in noise_levels_all:
    trial_errors = []

    for seed in range(n_trials):
        if nl == 0.0:
            pred = cnn_base_aligned.copy()
        else:
            set_torch_seed(seed)
            noise = nl * torch.randn_like(img)
            img_noisy = torch.clamp(img + noise, min=0.0)

            pred = reconstruct_nn_from_band(img_noisy)
            pred = maybe_align(pred, z, cnn_c_ref, dx_um)

        err = weighted_error(pred, cnn_base_aligned, cnn_weight)
        trial_errors.append(err)

    cnn_all_errors.append(trial_errors)

cnn_all_errors = np.asarray(cnn_all_errors, dtype=float)
if enforce_monotone_display:
    cnn_all_errors = monotone_curves_by_trial(cnn_all_errors)

cnn_medians = np.median(cnn_all_errors, axis=1)

# =========================
# statistical scan: GS
# =========================
gs_all_errors = []

for nl in noise_levels_all:
    trial_errors = []

    for seed in range(n_trials):
        if nl == 0.0:
            pred = gs_base_aligned.copy()
        else:
            pred = reconstruct_gs_from_true_profile(
                tgt_profile=tgt_norm,
                nl=nl,
                noise_seed=seed,
                gs_seed=gs_seed_fixed,
            )
            pred = maybe_align(pred, z, gs_c_ref, dx_um)

        err = weighted_error(pred, gs_base_aligned, gs_weight)
        trial_errors.append(err)

    gs_all_errors.append(trial_errors)

gs_all_errors = np.asarray(gs_all_errors, dtype=float)
if enforce_monotone_display:
    gs_all_errors = monotone_curves_by_trial(gs_all_errors)

gs_medians = np.median(gs_all_errors, axis=1)

# =========================
# plot 1: CNN
# =========================
fig, axes = plt.subplots(1, 2, figsize=(13, 5.2))
fig.subplots_adjust(bottom=0.18, wspace=0.28)

# left
ax1 = axes[0]
ax1.plot(z, cnn_base_aligned, color=baseline_color, linestyle="-", linewidth=2.2, label="0 noise")
for i, (nl, prof) in enumerate(cnn_rep_profiles):
    ax1.plot(
        z,
        prof,
        color=rep_colors[i],
        linestyle=rep_linestyles[i],
        linewidth=2.0,
        label=f"{nl*100:.2f}% noise",
    )
ax1.set_xlabel(xlabel_profile)
ax1.set_ylabel(cnn_left_ylabel)
ax1.set_title(cnn_left_title)
ax1.legend(loc=legend_loc)
ax1.grid(alpha=0.25)

# right
ax2 = axes[1]
positions = np.arange(len(noise_levels_all))
bp = ax2.boxplot(
    [cnn_all_errors[i] for i in range(len(noise_levels_all))],
    positions=positions,
    widths=0.6,
    patch_artist=True,
    showfliers=False,
    medianprops=dict(color=median_color, linewidth=2),
    whiskerprops=dict(color=box_fill_nn, linewidth=1.4),
    capprops=dict(color=box_fill_nn, linewidth=1.4),
    boxprops=dict(color=box_fill_nn, linewidth=1.4),
)
for patch in bp["boxes"]:
    patch.set_facecolor(box_fill_nn)
    patch.set_alpha(box_alpha)

ax2.plot(
    positions,
    cnn_medians,
    color=median_color,
    linewidth=2.2,
    marker="o",
    markersize=4,
    label="Median trend",
)

# ticks
tick_pos = [0, 1, len(noise_levels_all)//2, len(noise_levels_all)-1]
tick_lab = ["0", r"$10^{-4}$", r"$10^{-3}$", r"$10^{-2}$"]
ax2.set_xticks(tick_pos)
ax2.set_xticklabels(tick_lab)

ax2.set_xlabel(xlabel_noise)
ax2.set_ylabel(cnn_right_ylabel)
ax2.set_title(cnn_right_title)
ax2.legend(loc=legend_loc)
ax2.grid(axis="y", linestyle="--", alpha=0.25)

fig.text(0.5, 0.04, cnn_caption, ha="center", va="center")
plt.show()

# =========================
# plot 2: GS
# =========================
fig, axes = plt.subplots(1, 2, figsize=(13, 5.2))
fig.subplots_adjust(bottom=0.18, wspace=0.28)

# left
ax1 = axes[0]
ax1.plot(z, gs_base_aligned, color=baseline_color, linestyle="-", linewidth=2.2, label="0 noise")
for i, (nl, prof) in enumerate(gs_rep_profiles):
    ax1.plot(
        z,
        prof,
        color=rep_colors[i],
        linestyle=rep_linestyles[i],
        linewidth=2.0,
        label=f"{nl*100:.2f}% noise",
    )
ax1.set_xlabel(xlabel_profile)
ax1.set_ylabel(gs_left_ylabel)
ax1.set_title(gs_left_title)
ax1.legend(loc=legend_loc)
ax1.grid(alpha=0.25)

# right
ax2 = axes[1]
positions = np.arange(len(noise_levels_all))
bp = ax2.boxplot(
    [gs_all_errors[i] for i in range(len(noise_levels_all))],
    positions=positions,
    widths=0.6,
    patch_artist=True,
    showfliers=False,
    medianprops=dict(color=median_color, linewidth=2),
    whiskerprops=dict(color=box_fill_gs, linewidth=1.4),
    capprops=dict(color=box_fill_gs, linewidth=1.4),
    boxprops=dict(color=box_fill_gs, linewidth=1.4),
)
for patch in bp["boxes"]:
    patch.set_facecolor(box_fill_gs)
    patch.set_alpha(box_alpha)

ax2.plot(
    positions,
    gs_medians,
    color=median_color,
    linewidth=2.2,
    marker="o",
    markersize=4,
    label="Median trend",
)

ax2.set_xticks(tick_pos)
ax2.set_xticklabels(tick_lab)

ax2.set_xlabel(xlabel_noise)
ax2.set_ylabel(gs_right_ylabel)
ax2.set_title(gs_right_title)
ax2.legend(loc=legend_loc)
ax2.grid(axis="y", linestyle="--", alpha=0.25)

fig.text(0.5, 0.04, gs_caption, ha="center", va="center")
plt.show()

# %%
import importlib
import matplotlib.pyplot as plt
import src.prab_plot_style as prab_style
import src.quant_eval_plots as qep

prab_style = importlib.reload(prab_style)
qep = importlib.reload(qep)

print(qep.__file__)

# %%
vis_indices = (100, 101, 102)

comparison_cache = qep.build_quantitative_cache(
    model=model,
    val_dataset=val_dataset,
    tgt_files=tgt_files,
    target_folder=target_folder,
    device=device,
    dx_um=dx_um,
    f_min=f_min,
    f_max=f_max,
    f_display_max=f_display_max,
    pad_factor=pad_factor,
    compute_form_factor=compute_form_factor,
    k_to_THz=k_to_THz,
    forward_spectrum_fft=forward_spectrum_fft,
    gerchberg_saxton_1d_torch=gerchberg_saxton_1d_torch,
    fwhm_center=fwhm_center,
    align_by_fwhm=align_by_fwhm,
    n_random_samples=1000,
    sample_seed=0,
    gs_seeds=(0, 1, 2, 3, 4),
    gs_iters=2000,
    use_support=True,
    support_width_um=30.0,
    vis_indices=vis_indices,
    dense_vis_seed_count=100,
    model_name="1D dilated resnet",
)

qep.print_cache_summary(comparison_cache)

# %%
# ----- representative examples: draw separately, easy to modify in cell -----
for idx in vis_indices:
    fig, ax = qep.plot_representative_examples(
        comparison_cache,
        example_idx=idx,
        figsize=(7.2, 4.6),
        title=f"Validation sample {idx} (Double)",
        xlabel="z (μm)",
        ylabel=r"L1-normalized $\rho(z)$",
        target_label="Target",
        nn_label="1D dilated resnet",
        gs_label="GS envelope (5–95%, 100 seeds)",
        legend_loc="upper right",
    )
    # caption can be edited directly here
    fig.text(
        0.5,
        -0.02,
        f"Caption placeholder for sample {idx}.",
        ha="center",
        va="top",
        fontsize=11,
    )
    plt.show()

fig, ax = qep.plot_panel_a(
    comparison_cache,
    figsize=(7.2, 5.1),
    title="(a) Profile reconstruction error",
    ylabel="Profile NRMSE",
    xticklabels=("Single", "Double"),
    legend_loc="upper right",
)
fig.text(0.5, -0.02, "Caption placeholder for panel (a).", ha="center", va="top", fontsize=11)
plt.show()

fig, (ax_left, ax_right) = qep.plot_panel_bc_double(
    comparison_cache,
    figsize=(8.8, 5.0),
    title="Double-bunch spectral and separation errors",
    left_ylabel=r"$\|F_{\mathrm{rec}}-F_{\mathrm{meas}}\|_2 / \|F_{\mathrm{meas}}\|_2$",
    right_ylabel=r"$|\Delta \mathrm{separation}|$ (μm)",
    xticklabels=("Spectral mismatch", "Peak-separation error"),
    legend_loc="upper right",
)
fig.text(0.5, -0.02, "Caption placeholder for the combined double-bunch error plot.", ha="center", va="top", fontsize=11)
plt.show()

fig, ax, cbar = qep.plot_double_advantage_heatmap(
    comparison_cache,
    figsize=(7.6, 5.8),
    x_bins=10,
    y_bins=10,
    min_count_per_bin=3,
    title="Double-bunch advantage map (positive: dilated ResNet better)",
    xlabel=r"Left-bunch effective $\sigma$ (μm)",
    ylabel=r"Right-bunch effective $\sigma$ (μm)",
    cbar_label=r"$\Delta$accuracy = NRMSE$_{GS,med}$ - NRMSE$_{NN}$",
)
fig.text(0.5, -0.02, "Caption placeholder for the sigma-sigma advantage map.", ha="center", va="top", fontsize=11)
plt.show()
