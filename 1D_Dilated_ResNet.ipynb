# %%
# Cell 1: training imports

import os
import numpy as np

import torch
from torch.utils.data import DataLoader, random_split
from torch.utils.tensorboard import SummaryWriter
from torch.serialization import add_safe_globals

from src.dilated_resnet import (
    CTRDataset,
    DilatedResBlock,
    Dilated_CNN_ResNet,
    AsinhMSEWithPhysicsLoss,
    train_one_epoch,
    evaluate,
)

# %%
# Cell 2: basic config

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# Cell 3: paths, hyperparameters, and shared settings

img_folder = "./dataset/G1_G2/img"
target_folder = "./dataset/G1_G2/target"

num_exp = 40
sequence_length = 256
batch_size = 256
num_epochs = 200
learning_rate = 1e-3
val_ratio = 0.2
split_seed = 42

# shared plotting / physics settings
dx_um = 0.15
f_min = 50
f_max = 230
f_display_max = 250
pad_factor = 10

# %%
# Cell 4: dataset + fixed train/val split + dataloaders

img_files = sorted([f for f in os.listdir(img_folder) if f.endswith(".pt")])
tgt_files = sorted([f for f in os.listdir(target_folder) if f.endswith(".pt")])

full_dataset = CTRDataset(img_folder, target_folder, img_files, tgt_files, seq_len=sequence_length)
print("Total samples in dataset:", len(full_dataset))

num_total = len(full_dataset)
num_val = int(num_total * val_ratio)
num_train = num_total - num_val

split_generator = torch.Generator().manual_seed(split_seed)
train_dataset, val_dataset = random_split(
    full_dataset,
    [num_train, num_val],
    generator=split_generator,
)

print(f"Train samples: {num_train}, Val samples: {num_val}")

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Total samples in dataset: 90000
# Train samples: 72000, Val samples: 18000

# %%
# Cell 5: model + loss + optimizer

model = Dilated_CNN_ResNet(in_ch=1, base_ch=64).to(device)
criterion = AsinhMSEWithPhysicsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
# Cell 6: train and save checkpoints

writer = SummaryWriter(log_dir="./logs/exp{}".format(num_exp))
train_losses = []
val_losses = []

for epoch in range(1, num_epochs + 1):
    train_loss = train_one_epoch(model, train_loader, optimizer, criterion, device)
    val_loss = evaluate(model, val_loader, criterion, device)

    train_losses.append(train_loss)
    val_losses.append(val_loss)

    writer.add_scalar("Loss/train", train_loss, epoch)
    writer.add_scalar("Loss/val", val_loss, epoch)

    print(f"Epoch [{epoch:03d}/{num_epochs}] Train Loss: {train_loss:.6f}  |  Val Loss: {val_loss:.6f}")

    os.makedirs("./model/exp{}".format(num_exp), exist_ok=True)
    torch.save(model, "./model/exp{}/Dilated_ResNet_{}.pth".format(num_exp, epoch))

writer.close()
print("Training finished. Logs saved to ./logs/exp{}".format(num_exp))

# %%
# Cell 7: load model

add_safe_globals([DilatedResBlock, Dilated_CNN_ResNet])

model_path = "./model/exp{}/Dilated_ResNet_{}.pth".format(num_exp, num_epochs)
print("Loading model:", model_path)

model = torch.load(model_path, map_location=device, weights_only=False)
model.eval()
# Out:
# Loading model: ./model/exp40/Dilated_ResNet_200.pth
# Dilated_CNN_ResNet(
#   (in_conv): Conv1d(1, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#   (block1): DilatedResBlock(
#     (conv): Sequential(
#       (0): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#       (1): ReLU(inplace=True)
#       (2): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (block2): DilatedResBlock(
#     (conv): Sequential(
#       (0): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(4,), dilation=(2,))
#       (1): ReLU(inplace=True)
#       (2): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(4,), dilation=(2,))
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (block3): DilatedResBlock(
#     (conv): Sequential(
#       (0): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(8,), dilation=(4,))
#       (1): ReLU(inplace=True)
# ...

# %%
# Cell 8: validation / analysis imports and style
# ---- training and validation analysis are separated here on purpose ----

import importlib
import matplotlib.pyplot as plt

from src.form_factor_utils import (
    l1_nonneg_normalize,
    compute_form_factor,
    k_to_THz,
)
from src.reconstruction_utils import (
    fwhm_center,
    align_by_fwhm,
    weighted_error,
    gerchberg_saxton_1d_torch,
    forward_spectrum_fft,
    resample_linear,
)
import src.prab_plot_style as prab_style
import src.quant_eval_utils as qeu
import src.quant_eval_plots as qep
import src.notebook_eval_utils as neu

prab_style = importlib.reload(prab_style)
qeu = importlib.reload(qeu)
qep = importlib.reload(qep)
neu = importlib.reload(neu)

prab_style.setup_prab_style()
print("Validation utilities loaded.")
# Out:
# Validation utilities loaded.

# %%
# Cell 9: validation-set representative figure (3×2)
# ---- figure text stays editable here; src only prepares data / light plotting helpers ----

val_vis_indices = [100, 101, 102]

val_profile_titles = [f"Validation sample {idx}" for idx in val_vis_indices]
val_spectrum_titles = ["Spectral consistency"] * len(val_vis_indices)

val_cases = [
    neu.prepare_validation_case(
        model=model,
        val_dataset=val_dataset,
        idx=idx,
        device=device,
        dx_um=dx_um,
        f_min=f_min,
        f_max=f_max,
        f_display_max=f_display_max,
        pad_factor=pad_factor,
        compute_form_factor=compute_form_factor,
        k_to_THz=k_to_THz,
    )
    for idx in val_vis_indices
]

fig, axes = plt.subplots(len(val_cases), 2, figsize=(13, 11))
fig.suptitle("Validation Set: Multi-Gaussian Reconstruction under Finite Bandwidth", fontsize=15)

for row, case in enumerate(val_cases):
    qep.plot_profile_pair(
        axes[row, 0],
        z_um=case["z_um"],
        target=case["target"],
        prediction=case["prediction"],
        target_label="True",
        prediction_label="Reconstruction",
        prediction_color="#E66100",
        xlabel="z (μm)",
        ylabel="Normalized charge",
        title=val_profile_titles[row],
        legend_loc="upper right",
    )
    qep.plot_spectrum_pair(
        axes[row, 1],
        freq_meas=case["freq_meas"],
        measured_band=case["measured_band"],
        freq_full=case["freq_full"],
        reconstructed_full=case["reconstructed_full"],
        f_min=case["f_min"],
        f_max=case["f_max"],
        f_display_max=case["f_display_max"],
        measured_label="True",
        reconstructed_label="Reconstruction",
        reconstructed_color="#E66100",
        xlabel="Frequency (THz)",
        ylabel="Normalized |F|² (band-max)",
        title=val_spectrum_titles[row],
        legend_loc="upper right",
        normalize_mode="band-max",
    )

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
# Cell 10: BubbleWrap preprocessing + reconstruction figure
# ---- common CSV / resampling logic is in src; panel text stays here ----

bubble_cfg = {
    "folder": "./app/form factor/bubble wrap",
    "target_points": 256,
    "file_order": [
        "F1.csv", "F2.csv", "F3.csv",
        "rho1.csv", "rho2.csv", "rho3.csv",
    ],
    "titles": ["Profile 1", "Profile 2", "Profile 3"],
}

bubble_cases = neu.load_bubblewrap_cases(
    folder=bubble_cfg["folder"],
    dx_um=dx_um,
    f_min=f_min,
    f_max=f_max,
    target_points=bubble_cfg["target_points"],
    resample_fn=resample_linear,
    file_order=bubble_cfg["file_order"],
)

bubble_payloads = [
    neu.prepare_bubblewrap_case(
        model=model,
        band_power=case["band_power"],
        target_profile=case["target_profile"],
        device=device,
        dx_um=dx_um,
        f_min=f_min,
        f_max=f_max,
        f_display_max=f_display_max,
        pad_factor=pad_factor,
        compute_form_factor=compute_form_factor,
        k_to_THz=k_to_THz,
    )
    for case in bubble_cases
]

fig, axes = plt.subplots(2, len(bubble_payloads), figsize=(15, 8))
fig.suptitle("BubbleWrap → CNN Reconstruction", fontsize=15)

for col, payload in enumerate(bubble_payloads):
    qep.plot_profile_pair(
        axes[0, col],
        z_um=payload["z_um"],
        target=payload["target"],
        prediction=payload["prediction"],
        target_label="BubbleWrap",
        prediction_label="CNN Reconstruction",
        prediction_color="#E66100",
        xlabel="z (μm)",
        ylabel="Normalized charge",
        title=bubble_cfg["titles"][col],
        legend_loc="upper right",
    )
    qep.plot_spectrum_pair(
        axes[1, col],
        freq_meas=payload["freq_meas"],
        measured_band=payload["measured_band"],
        freq_full=payload["freq_full"],
        reconstructed_full=payload["reconstructed_full"],
        f_min=payload["f_min"],
        f_max=payload["f_max"],
        f_display_max=payload["f_display_max"],
        measured_label="Measured spectrum",
        reconstructed_label="Forward (CNN)",
        reconstructed_color="#E66100",
        xlabel="Frequency (THz)",
        ylabel="Normalized |F|² (band-max)",
        title="Spectral consistency",
        legend_loc="upper right",
        normalize_mode="band-max",
    )

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# Cell 11: noise robustness
# ---- diagnostics in src, visual wording and figure composition in the cell ----

noise_cfg = {
    "idx": 100,
    "rep_levels": (1e-2, 5e-2),
    "rep_labels": ("1% noise", "5% noise"),
    "rep_colors": ("#4C72B0", "#DD8452"),
    "rep_linestyles": ("--", "-."),
    "right_noise_levels": np.logspace(np.log10(1e-4), np.log10(1e-2), 15),
    "n_trials": 50,
    "gs_seed_fixed": 0,
    "gs_iters": 2000,
    "use_support": True,
    "support_width_um": 30.0,
}

diag_nn = qeu.get_noise_robustness_nn_diagnostics(
    model=model,
    val_dataset=val_dataset,
    idx=noise_cfg["idx"],
    device=device,
    dx_um=dx_um,
    fwhm_center=fwhm_center,
    align_by_fwhm=align_by_fwhm,
    rep_levels=noise_cfg["rep_levels"],
    right_noise_levels=noise_cfg["right_noise_levels"],
    n_trials=noise_cfg["n_trials"],
)

diag_gs = qeu.get_noise_robustness_gs_diagnostics(
    val_dataset=val_dataset,
    idx=noise_cfg["idx"],
    device=device,
    dx_um=dx_um,
    fwhm_center=fwhm_center,
    align_by_fwhm=align_by_fwhm,
    forward_spectrum_fft=forward_spectrum_fft,
    gerchberg_saxton_1d_torch=gerchberg_saxton_1d_torch,
    rep_levels=noise_cfg["rep_levels"],
    right_noise_levels=noise_cfg["right_noise_levels"],
    n_trials=noise_cfg["n_trials"],
    gs_seed_fixed=noise_cfg["gs_seed_fixed"],
    gs_iters=noise_cfg["gs_iters"],
    use_support=noise_cfg["use_support"],
    support_width_um=noise_cfg["support_width_um"],
)

fig, ax = plt.subplots(1, 1, figsize=(6.4, 5.0))
qep.plot_noise_profile_set(
    ax,
    diag_nn,
    baseline_label="0 noise",
    rep_labels=noise_cfg["rep_labels"],
    baseline_color="black",
    rep_colors=noise_cfg["rep_colors"],
    rep_linestyles=noise_cfg["rep_linestyles"],
    xlabel="z (μm)",
    ylabel="Normalized charge",
    title="1D dilated ResNet reconstruction under spectral noise",
    legend_loc="upper right",
)
fig.text(0.5, -0.02, "Caption placeholder for CNN profile robustness.", ha="center", va="top", fontsize=11)
plt.show()

fig, ax = plt.subplots(1, 1, figsize=(6.4, 5.0))
qep.plot_noise_profile_set(
    ax,
    diag_gs,
    baseline_label="0 noise",
    rep_labels=noise_cfg["rep_labels"],
    baseline_color="black",
    rep_colors=noise_cfg["rep_colors"],
    rep_linestyles=noise_cfg["rep_linestyles"],
    xlabel="z (μm)",
    ylabel="Normalized charge",
    title="GS reconstruction under spectral noise",
    legend_loc="upper right",
)
fig.text(0.5, -0.02, "Caption placeholder for GS profile robustness.", ha="center", va="top", fontsize=11)
plt.show()

fig, ax = plt.subplots(1, 1, figsize=(7.2, 5.0))
qep.plot_noise_comparison(
    ax,
    [diag_nn, diag_gs],
    xlabel="Noise level",
    ylabel="Peak-weighted relative error to zero-noise output",
    title="Noise robustness comparison",
    legend_loc="upper left",
    xscale="log",
    curve_labels=("1D dilated ResNet", "GS"),
    curve_colors=("#E66100", "#2C7FB8"),
    curve_linestyles=("-", "--"),
    show_boxes=True,
    box_alpha=0.14,
    show_zero_reference=True,
    baseline_color="black",
)
fig.text(0.5, -0.02, "Caption placeholder for NN-vs-GS noise robustness comparison.", ha="center", va="top", fontsize=11)
plt.show()

# %%
# Cell 12: quantitative cache
# ---- allow_gs_double_swap is the new switch for treating swapped double peaks as acceptable ----

quant_cfg = {
    "vis_indices": (100, 101, 102),
    "n_random_samples": 1000,
    "sample_seed": 0,
    "gs_seeds": (0, 1, 2),
    "gs_iters": 2000,
    "use_support": True,
    "support_width_um": 30.0,
    "dense_vis_seed_count": 100,
    "allow_gs_double_swap": True,   # <-- set False to recover the old behavior
}

comparison_cache = qeu.build_quantitative_cache(
    model=model,
    val_dataset=val_dataset,
    tgt_files=tgt_files,
    target_folder=target_folder,
    device=device,
    dx_um=dx_um,
    f_min=f_min,
    f_max=f_max,
    f_display_max=f_display_max,
    pad_factor=pad_factor,
    compute_form_factor=compute_form_factor,
    k_to_THz=k_to_THz,
    forward_spectrum_fft=forward_spectrum_fft,
    gerchberg_saxton_1d_torch=gerchberg_saxton_1d_torch,
    fwhm_center=fwhm_center,
    align_by_fwhm=align_by_fwhm,
    n_random_samples=quant_cfg["n_random_samples"],
    sample_seed=quant_cfg["sample_seed"],
    gs_seeds=quant_cfg["gs_seeds"],
    gs_iters=quant_cfg["gs_iters"],
    use_support=quant_cfg["use_support"],
    support_width_um=quant_cfg["support_width_um"],
    vis_indices=quant_cfg["vis_indices"],
    dense_vis_seed_count=quant_cfg["dense_vis_seed_count"],
    model_name="1D dilated resnet",
    allow_gs_double_swap=quant_cfg["allow_gs_double_swap"],
)

qeu.print_cache_summary(comparison_cache)
# Out:
# Selected validation samples
#   total: 1000
#   forced vis indices in cache: (100, 101, 102)
#   Single: 128
#   Double: 872
#
# Timing summary
# --------------
#  1D dilated resnet: 1.35 ± 0.35 ms  (n=1000)
#                 GS: 573.70 ± 35.26 ms  (n=1000)
#
# Metric summary (median [Q1, Q3])
# ---------------------------------
#
# [profile_nrmse]
# Single |  1D dilated resnet : 0.1132 [0.0732, 0.1681]  n=128
# Single |                 GS : 0.1253 [0.0593, 0.2068]  n=128
# Double |  1D dilated resnet : 0.1656 [0.1150, 0.2435]  n=872
# Double |                 GS : 0.2182 [0.1272, 0.3288]  n=872
#
# [spectral_error]
# Single |  1D dilated resnet : 0.0604 [0.0362, 0.0992]  n=128
# Single |                 GS : 0.0455 [0.0294, 0.0988]  n=128
# Double |  1D dilated resnet : 0.0888 [0.0598, 0.1440]  n=872
# Double |                 GS : 0.0962 [0.0492, 0.2107]  n=872
#
# [structure_error]
# Single |  1D dilated resnet : 0.1500 [0.0000, 0.1500]  n=128
# ...

# %%
# Cell 13: quantitative figures
# ---- figure details stay here; src only provides cache + light plotting primitives ----

for idx in quant_cfg["vis_indices"]:
    ex = comparison_cache["sample_records"][idx]
    z_um = qeu.centered_axis(len(ex["target"]), comparison_cache["config"]["dx_um"])

    fig, ax = plt.subplots(1, 1, figsize=(7.2, 4.6))
    gs_label = f"GS envelope (5–95%, {ex['dense_vis_seed_count']} seeds)"
    if comparison_cache["config"]["allow_gs_double_swap"] and np.isfinite(ex.get("dense_gs_flip_fraction", np.nan)):
        gs_label += f", flip frac.={ex['dense_gs_flip_fraction']:.2f}"

    qep.plot_profile_envelope(
        ax,
        z_um=z_um,
        target=ex["target"],
        nn_prediction=ex["nn_pred"],
        gs_quantiles=ex["dense_gs_quantiles"],
        target_label="Target",
        nn_label="1D dilated resnet",
        gs_label=gs_label,
        xlabel="z (μm)",
        ylabel=r"L1-normalized $\rho(z)$",
        title=f"Validation sample {idx} ({ex['group']})",
        legend_loc="upper right",
    )
    fig.text(0.5, -0.02, f"Caption placeholder for sample {idx}.", ha="center", va="top", fontsize=11)
    plt.show()

fig, ax = plt.subplots(1, 1, figsize=(7.2, 5.1))
qep.grouped_method_boxplot(
    ax,
    comparison_cache["metrics"]["profile_nrmse"],
    groups=qeu.GROUP_ORDER,
    methods=[comparison_cache["config"]["model_name"], qeu.METHOD_GS],
    colors={
        comparison_cache["config"]["model_name"]: qep.COLORS[qeu.METHOD_NN],
        qeu.METHOD_GS: qep.COLORS[qeu.METHOD_GS],
    },
    xticklabels=("Single", "Double"),
    ylabel="Profile NRMSE",
    title="(a) Profile reconstruction error",
    show_legend=True,
    legend_loc="upper right",
)
fig.text(0.5, -0.02, "Caption placeholder for panel (a).", ha="center", va="top", fontsize=11)
plt.show()

fig, ax_left = plt.subplots(1, 1, figsize=(8.8, 5.0))
ax_right = ax_left.twinx()
qep.paired_metric_boxplot(
    ax_left,
    ax_right,
    left_values=(
        comparison_cache["metrics"]["spectral_error"][("Double", comparison_cache["config"]["model_name"])],
        comparison_cache["metrics"]["spectral_error"][("Double", qeu.METHOD_GS)],
    ),
    right_values=(
        comparison_cache["metrics"]["structure_error"][("Double", comparison_cache["config"]["model_name"])],
        comparison_cache["metrics"]["structure_error"][("Double", qeu.METHOD_GS)],
    ),
    method_order=[comparison_cache["config"]["model_name"], qeu.METHOD_GS],
    colors={
        comparison_cache["config"]["model_name"]: qep.COLORS[qeu.METHOD_NN],
        qeu.METHOD_GS: qep.COLORS[qeu.METHOD_GS],
    },
    xticklabels=("Spectral mismatch", "Peak-separation error"),
    left_ylabel=r"$\|F_{\mathrm{rec}}-F_{\mathrm{meas}}\|_2 / \|F_{\mathrm{meas}}\|_2$",
    right_ylabel=r"$|\Delta \mathrm{separation}|$ (μm)",
    title="Double-bunch spectral and separation errors",
    legend_loc="upper right",
)
fig.text(0.5, -0.02, "Caption placeholder for the combined double-bunch error plot.", ha="center", va="top", fontsize=11)
plt.show()

heatmap_cfg = {
    "grid_size": (240, 240),
    "method": "linear",
    "fill_nearest": True,
    "smooth_sigma": 0.8,
    "show_points": False,
}

heatmap_data = qeu.build_interpolated_advantage_map(
    comparison_cache,
    grid_size=heatmap_cfg["grid_size"],
    method=heatmap_cfg["method"],
    fill_nearest=heatmap_cfg["fill_nearest"],
    smooth_sigma=heatmap_cfg["smooth_sigma"],
)

fig, ax = plt.subplots(1, 1, figsize=(7.6, 5.8))
_, cbar = qep.plot_interpolated_heatmap(
    ax,
    heatmap_data,
    fig=fig,
    title="Double-bunch advantage map (positive: dilated ResNet better)",
    xlabel=r"Left-bunch effective $\sigma$ (μm)",
    ylabel=r"Right-bunch effective $\sigma$ (μm)",
    cbar_label=r"$\Delta$accuracy = NRMSE$_{GS,med}$ - NRMSE$_{NN}$",
    show_points=heatmap_cfg["show_points"],
)
fig.text(0.5, -0.02, "Caption placeholder for the sigma-sigma advantage map.", ha="center", va="top", fontsize=11)
plt.show()
