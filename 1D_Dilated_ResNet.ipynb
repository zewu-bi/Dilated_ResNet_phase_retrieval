# %%
# Cell 1: imports

import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
from torch.utils.data import DataLoader, random_split
from torch.utils.tensorboard import SummaryWriter
from torch.serialization import add_safe_globals

from src.dilated_resnet import (
    CTRDataset,
    DilatedResBlock,
    Dilated_CNN_ResNet,
    AsinhMSEWithPhysicsLoss,
    train_one_epoch,
    evaluate,
)
from src.form_factor_utils import (
    l1_nonneg_normalize,
    compute_form_factor,
    k_to_THz,
)
from src.reconstruction_utils import (
    fwhm_center,
    align_by_fwhm,
    weighted_error,
    gerchberg_saxton_1d_torch,
    forward_spectrum_fft,
    resample_linear,
)

# %%
# Cell 2: basic config

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# Cell 3: paths, hyperparameters, and shared settings

img_folder    = "./dataset/G1_G2_g_f_s_a/img"
target_folder = "./dataset/G1_G2_g_f_s_a/target"

num_exp = 39
sequence_length = 256
batch_size = 256
num_epochs = 200
learning_rate = 1e-3
val_ratio = 0.2
split_seed = 42

# shared plotting / physics settings
dx_um = 0.15
f_min = 50
f_max = 230
f_display_max = 250
pad_factor = 10

# %%
# Cell 4: dataset + fixed train/val split + dataloaders

img_files = sorted([f for f in os.listdir(img_folder) if f.endswith(".pt")])
tgt_files = sorted([f for f in os.listdir(target_folder) if f.endswith(".pt")])

# print("Number of img files   :", len(img_files))
# print("Number of target files:", len(tgt_files))

full_dataset = CTRDataset(img_folder, target_folder, img_files, tgt_files, seq_len=sequence_length)
print("Total samples in dataset:", len(full_dataset))

num_total = len(full_dataset)
num_val = int(num_total * val_ratio)
num_train = num_total - num_val

split_generator = torch.Generator().manual_seed(split_seed)
train_dataset, val_dataset = random_split(
    full_dataset,
    [num_train, num_val],
    generator=split_generator,
)

print(f"Train samples: {num_train}, Val samples: {num_val}")
# print("First 5 val indices:", val_dataset.indices[:5])

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Total samples in dataset: 25000
# Train samples: 20000, Val samples: 5000

# %%
# Cell 5: model + loss + optimizer + train/eval loops

model = Dilated_CNN_ResNet(in_ch=1, base_ch=64).to(device)
criterion = AsinhMSEWithPhysicsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
# Cell 6: train and save checkpoints

writer = SummaryWriter(log_dir="./logs/exp{}".format(num_exp))
train_losses = []
val_losses = []

for epoch in range(1, num_epochs + 1):
    train_loss = train_one_epoch(model, train_loader, optimizer, criterion, device)
    val_loss = evaluate(model, val_loader, criterion, device)

    train_losses.append(train_loss)
    val_losses.append(val_loss)

    writer.add_scalar("Loss/train", train_loss, epoch)
    writer.add_scalar("Loss/val", val_loss, epoch)

    print(f"Epoch [{epoch:03d}/{num_epochs}] Train Loss: {train_loss:.6f}  |  Val Loss: {val_loss:.6f}")

    os.makedirs("./model/exp{}".format(num_exp), exist_ok=True)
    torch.save(model, "./model/exp{}/Dilated_ResNet_{}.pth".format(num_exp, epoch))

writer.close()
print("Training finished. Logs saved to ./logs/exp{}".format(num_exp))
# Out:
# Epoch [001/200] Train Loss: 0.039508  |  Val Loss: 0.030516
# Epoch [002/200] Train Loss: 0.027576  |  Val Loss: 0.023727
# Epoch [003/200] Train Loss: 0.018403  |  Val Loss: 0.016550
# Epoch [004/200] Train Loss: 0.013641  |  Val Loss: 0.013167
# Epoch [005/200] Train Loss: 0.011435  |  Val Loss: 0.011464
# Epoch [006/200] Train Loss: 0.010061  |  Val Loss: 0.012162
# Epoch [007/200] Train Loss: 0.009674  |  Val Loss: 0.010272
# Epoch [008/200] Train Loss: 0.008825  |  Val Loss: 0.009841
# Epoch [009/200] Train Loss: 0.008374  |  Val Loss: 0.009337
# Epoch [010/200] Train Loss: 0.008134  |  Val Loss: 0.008647
# Epoch [011/200] Train Loss: 0.007771  |  Val Loss: 0.008978
# Epoch [012/200] Train Loss: 0.007786  |  Val Loss: 0.008128
# Epoch [013/200] Train Loss: 0.007364  |  Val Loss: 0.009161
# Epoch [014/200] Train Loss: 0.007343  |  Val Loss: 0.009331
# Epoch [015/200] Train Loss: 0.007360  |  Val Loss: 0.007405
# Epoch [016/200] Train Loss: 0.006813  |  Val Loss: 0.007164
# Epoch [017/200] Train Loss: 0.006752  |  Val Loss: 0.007124
# Epoch [018/200] Train Loss: 0.006516  |  Val Loss: 0.007398
# Epoch [019/200] Train Loss: 0.006463  |  Val Loss: 0.007010
# Epoch [020/200] Train Loss: 0.006443  |  Val Loss: 0.006645
# Epoch [021/200] Train Loss: 0.006233  |  Val Loss: 0.006884
# Epoch [022/200] Train Loss: 0.006307  |  Val Loss: 0.006900
# Epoch [023/200] Train Loss: 0.006068  |  Val Loss: 0.006870
# Epoch [024/200] Train Loss: 0.006091  |  Val Loss: 0.006562
# Epoch [025/200] Train Loss: 0.005884  |  Val Loss: 0.006493
# Epoch [026/200] Train Loss: 0.005831  |  Val Loss: 0.007073
# Epoch [027/200] Train Loss: 0.005899  |  Val Loss: 0.006297
# Epoch [028/200] Train Loss: 0.005726  |  Val Loss: 0.006540
# Epoch [029/200] Train Loss: 0.005708  |  Val Loss: 0.006052
# Epoch [030/200] Train Loss: 0.005518  |  Val Loss: 0.006761
# Epoch [031/200] Train Loss: 0.005473  |  Val Loss: 0.005790
# Epoch [032/200] Train Loss: 0.005445  |  Val Loss: 0.006097
# Epoch [033/200] Train Loss: 0.005360  |  Val Loss: 0.005892
# Epoch [034/200] Train Loss: 0.005276  |  Val Loss: 0.005748
# Epoch [035/200] Train Loss: 0.005175  |  Val Loss: 0.006406
# Epoch [036/200] Train Loss: 0.005276  |  Val Loss: 0.005691
# Epoch [037/200] Train Loss: 0.005168  |  Val Loss: 0.005610
# Epoch [038/200] Train Loss: 0.004979  |  Val Loss: 0.005569
# Epoch [039/200] Train Loss: 0.004996  |  Val Loss: 0.005726
# Epoch [040/200] Train Loss: 0.005014  |  Val Loss: 0.005399
# Epoch [041/200] Train Loss: 0.004862  |  Val Loss: 0.005311
# Epoch [042/200] Train Loss: 0.004820  |  Val Loss: 0.005398
# Epoch [043/200] Train Loss: 0.004843  |  Val Loss: 0.005618
# Epoch [044/200] Train Loss: 0.004792  |  Val Loss: 0.005360
# Epoch [045/200] Train Loss: 0.004575  |  Val Loss: 0.005644
# Epoch [046/200] Train Loss: 0.004709  |  Val Loss: 0.005389
# Epoch [047/200] Train Loss: 0.004846  |  Val Loss: 0.005235
# Epoch [048/200] Train Loss: 0.004597  |  Val Loss: 0.005220
# Epoch [049/200] Train Loss: 0.004460  |  Val Loss: 0.005070
# Epoch [050/200] Train Loss: 0.004497  |  Val Loss: 0.005501
# Epoch [051/200] Train Loss: 0.004510  |  Val Loss: 0.005692
# Epoch [052/200] Train Loss: 0.004533  |  Val Loss: 0.005745
# Epoch [053/200] Train Loss: 0.004522  |  Val Loss: 0.005847
# Epoch [054/200] Train Loss: 0.004447  |  Val Loss: 0.005127
# Epoch [055/200] Train Loss: 0.004232  |  Val Loss: 0.004860
# Epoch [056/200] Train Loss: 0.004159  |  Val Loss: 0.004883
# Epoch [057/200] Train Loss: 0.004256  |  Val Loss: 0.004971
# Epoch [058/200] Train Loss: 0.004189  |  Val Loss: 0.005911
# Epoch [059/200] Train Loss: 0.004181  |  Val Loss: 0.004708
# Epoch [060/200] Train Loss: 0.004062  |  Val Loss: 0.004712
# Epoch [061/200] Train Loss: 0.003996  |  Val Loss: 0.004871
# Epoch [062/200] Train Loss: 0.003956  |  Val Loss: 0.004717
# Epoch [063/200] Train Loss: 0.003820  |  Val Loss: 0.004737
# Epoch [064/200] Train Loss: 0.003916  |  Val Loss: 0.004842
# Epoch [065/200] Train Loss: 0.003843  |  Val Loss: 0.004637
# Epoch [066/200] Train Loss: 0.003761  |  Val Loss: 0.004868
# Epoch [067/200] Train Loss: 0.003814  |  Val Loss: 0.005318
# Epoch [068/200] Train Loss: 0.003789  |  Val Loss: 0.004488
# Epoch [069/200] Train Loss: 0.003755  |  Val Loss: 0.004441
# Epoch [070/200] Train Loss: 0.003669  |  Val Loss: 0.004803
# Epoch [071/200] Train Loss: 0.003724  |  Val Loss: 0.004415
# Epoch [072/200] Train Loss: 0.003589  |  Val Loss: 0.004434
# Epoch [073/200] Train Loss: 0.003582  |  Val Loss: 0.004707
# Epoch [074/200] Train Loss: 0.003570  |  Val Loss: 0.006290
# Epoch [075/200] Train Loss: 0.003957  |  Val Loss: 0.005219
# Epoch [076/200] Train Loss: 0.003687  |  Val Loss: 0.004395
# Epoch [077/200] Train Loss: 0.003426  |  Val Loss: 0.004501
# Epoch [078/200] Train Loss: 0.003438  |  Val Loss: 0.004367
# Epoch [079/200] Train Loss: 0.003430  |  Val Loss: 0.004633
# Epoch [080/200] Train Loss: 0.003430  |  Val Loss: 0.004571
# Epoch [081/200] Train Loss: 0.003362  |  Val Loss: 0.004316
# Epoch [082/200] Train Loss: 0.003300  |  Val Loss: 0.004393
# Epoch [083/200] Train Loss: 0.003235  |  Val Loss: 0.004871
# Epoch [084/200] Train Loss: 0.003301  |  Val Loss: 0.004404
# Epoch [085/200] Train Loss: 0.003246  |  Val Loss: 0.004301
# Epoch [086/200] Train Loss: 0.003378  |  Val Loss: 0.004361
# Epoch [087/200] Train Loss: 0.003347  |  Val Loss: 0.004617
# Epoch [088/200] Train Loss: 0.003197  |  Val Loss: 0.004387
# Epoch [089/200] Train Loss: 0.003103  |  Val Loss: 0.004157
# Epoch [090/200] Train Loss: 0.003126  |  Val Loss: 0.004293
# Epoch [091/200] Train Loss: 0.003036  |  Val Loss: 0.004443
# Epoch [092/200] Train Loss: 0.003068  |  Val Loss: 0.004433
# Epoch [093/200] Train Loss: 0.003035  |  Val Loss: 0.004665
# Epoch [094/200] Train Loss: 0.003237  |  Val Loss: 0.004232
# Epoch [095/200] Train Loss: 0.003000  |  Val Loss: 0.004109
# Epoch [096/200] Train Loss: 0.002952  |  Val Loss: 0.004356
# Epoch [097/200] Train Loss: 0.003088  |  Val Loss: 0.004212
# Epoch [098/200] Train Loss: 0.002902  |  Val Loss: 0.004273
# Epoch [099/200] Train Loss: 0.002917  |  Val Loss: 0.004324
# Epoch [100/200] Train Loss: 0.002911  |  Val Loss: 0.004567
# Epoch [101/200] Train Loss: 0.002863  |  Val Loss: 0.004088
# Epoch [102/200] Train Loss: 0.002866  |  Val Loss: 0.004109
# Epoch [103/200] Train Loss: 0.002968  |  Val Loss: 0.004589
# Epoch [104/200] Train Loss: 0.003128  |  Val Loss: 0.004162
# Epoch [105/200] Train Loss: 0.002851  |  Val Loss: 0.004750
# Epoch [106/200] Train Loss: 0.002908  |  Val Loss: 0.004320
# Epoch [107/200] Train Loss: 0.002799  |  Val Loss: 0.004399
# Epoch [108/200] Train Loss: 0.002773  |  Val Loss: 0.004011
# Epoch [109/200] Train Loss: 0.002748  |  Val Loss: 0.004120
# Epoch [110/200] Train Loss: 0.002670  |  Val Loss: 0.004035
# Epoch [111/200] Train Loss: 0.002687  |  Val Loss: 0.004229
# Epoch [112/200] Train Loss: 0.002800  |  Val Loss: 0.004086
# Epoch [113/200] Train Loss: 0.002629  |  Val Loss: 0.004074
# Epoch [114/200] Train Loss: 0.002584  |  Val Loss: 0.003895
# Epoch [115/200] Train Loss: 0.002575  |  Val Loss: 0.004388
# Epoch [116/200] Train Loss: 0.002772  |  Val Loss: 0.004554
# Epoch [117/200] Train Loss: 0.002580  |  Val Loss: 0.004083
# Epoch [118/200] Train Loss: 0.002501  |  Val Loss: 0.003993
# Epoch [119/200] Train Loss: 0.002500  |  Val Loss: 0.003853
# Epoch [120/200] Train Loss: 0.002628  |  Val Loss: 0.004011
# Epoch [121/200] Train Loss: 0.002517  |  Val Loss: 0.003979
# Epoch [122/200] Train Loss: 0.002422  |  Val Loss: 0.003930
# Epoch [123/200] Train Loss: 0.002534  |  Val Loss: 0.004111
# Epoch [124/200] Train Loss: 0.002445  |  Val Loss: 0.004259
# Epoch [125/200] Train Loss: 0.002712  |  Val Loss: 0.003946
# Epoch [126/200] Train Loss: 0.002594  |  Val Loss: 0.003975
# Epoch [127/200] Train Loss: 0.002425  |  Val Loss: 0.003954
# Epoch [128/200] Train Loss: 0.002412  |  Val Loss: 0.003874
# Epoch [129/200] Train Loss: 0.002395  |  Val Loss: 0.004259
# Epoch [130/200] Train Loss: 0.002419  |  Val Loss: 0.004567
# Epoch [131/200] Train Loss: 0.002674  |  Val Loss: 0.004095
# Epoch [132/200] Train Loss: 0.002616  |  Val Loss: 0.004018
# Epoch [133/200] Train Loss: 0.002802  |  Val Loss: 0.004039
# Epoch [134/200] Train Loss: 0.002460  |  Val Loss: 0.004212
# Epoch [135/200] Train Loss: 0.002471  |  Val Loss: 0.003949
# Epoch [136/200] Train Loss: 0.002369  |  Val Loss: 0.003901
# Epoch [137/200] Train Loss: 0.002316  |  Val Loss: 0.004341
# Epoch [138/200] Train Loss: 0.002315  |  Val Loss: 0.003888
# Epoch [139/200] Train Loss: 0.002246  |  Val Loss: 0.003952
# Epoch [140/200] Train Loss: 0.002184  |  Val Loss: 0.004008
# Epoch [141/200] Train Loss: 0.002263  |  Val Loss: 0.003744
# Epoch [142/200] Train Loss: 0.002147  |  Val Loss: 0.004044
# Epoch [143/200] Train Loss: 0.002221  |  Val Loss: 0.003808
# Epoch [144/200] Train Loss: 0.002191  |  Val Loss: 0.003789
# Epoch [145/200] Train Loss: 0.002161  |  Val Loss: 0.003989
# Epoch [146/200] Train Loss: 0.002352  |  Val Loss: 0.003932
# Epoch [147/200] Train Loss: 0.002264  |  Val Loss: 0.003895
# Epoch [148/200] Train Loss: 0.002110  |  Val Loss: 0.003909
# Epoch [149/200] Train Loss: 0.002121  |  Val Loss: 0.003906
# Epoch [150/200] Train Loss: 0.002146  |  Val Loss: 0.004016
# Epoch [151/200] Train Loss: 0.002036  |  Val Loss: 0.004090
# Epoch [152/200] Train Loss: 0.002173  |  Val Loss: 0.003794
# Epoch [153/200] Train Loss: 0.002183  |  Val Loss: 0.005256
# Epoch [154/200] Train Loss: 0.003108  |  Val Loss: 0.004040
# Epoch [155/200] Train Loss: 0.002590  |  Val Loss: 0.004073
# Epoch [156/200] Train Loss: 0.002235  |  Val Loss: 0.003852
# Epoch [157/200] Train Loss: 0.002063  |  Val Loss: 0.003687
# Epoch [158/200] Train Loss: 0.002089  |  Val Loss: 0.003842
# Epoch [159/200] Train Loss: 0.001991  |  Val Loss: 0.003809
# Epoch [160/200] Train Loss: 0.002034  |  Val Loss: 0.003816
# Epoch [161/200] Train Loss: 0.001919  |  Val Loss: 0.003872
# Epoch [162/200] Train Loss: 0.001916  |  Val Loss: 0.003992
# Epoch [163/200] Train Loss: 0.002056  |  Val Loss: 0.003779
# Epoch [164/200] Train Loss: 0.002034  |  Val Loss: 0.003817
# Epoch [165/200] Train Loss: 0.001889  |  Val Loss: 0.004010
# Epoch [166/200] Train Loss: 0.001899  |  Val Loss: 0.003748
# Epoch [167/200] Train Loss: 0.001897  |  Val Loss: 0.003825
# Epoch [168/200] Train Loss: 0.001830  |  Val Loss: 0.003777
# Epoch [169/200] Train Loss: 0.001827  |  Val Loss: 0.003807
# Epoch [170/200] Train Loss: 0.001842  |  Val Loss: 0.003905
# Epoch [171/200] Train Loss: 0.002059  |  Val Loss: 0.003787
# Epoch [172/200] Train Loss: 0.001863  |  Val Loss: 0.003951
# Epoch [173/200] Train Loss: 0.001854  |  Val Loss: 0.003878
# Epoch [174/200] Train Loss: 0.001884  |  Val Loss: 0.003876
# Epoch [175/200] Train Loss: 0.001857  |  Val Loss: 0.003907
# Epoch [176/200] Train Loss: 0.001884  |  Val Loss: 0.003776
# Epoch [177/200] Train Loss: 0.001808  |  Val Loss: 0.003992
# Epoch [178/200] Train Loss: 0.002110  |  Val Loss: 0.003822
# Epoch [179/200] Train Loss: 0.001937  |  Val Loss: 0.003902
# Epoch [180/200] Train Loss: 0.001957  |  Val Loss: 0.003907
# Epoch [181/200] Train Loss: 0.001869  |  Val Loss: 0.003866
# Epoch [182/200] Train Loss: 0.001776  |  Val Loss: 0.004070
# Epoch [183/200] Train Loss: 0.001829  |  Val Loss: 0.003809
# Epoch [184/200] Train Loss: 0.001837  |  Val Loss: 0.003795
# Epoch [185/200] Train Loss: 0.001774  |  Val Loss: 0.003852
# Epoch [186/200] Train Loss: 0.001699  |  Val Loss: 0.003994
# Epoch [187/200] Train Loss: 0.001849  |  Val Loss: 0.003826
# Epoch [188/200] Train Loss: 0.001972  |  Val Loss: 0.003972
# Epoch [189/200] Train Loss: 0.001798  |  Val Loss: 0.003853
# Epoch [190/200] Train Loss: 0.001809  |  Val Loss: 0.003805
# Epoch [191/200] Train Loss: 0.001788  |  Val Loss: 0.004346
# Epoch [192/200] Train Loss: 0.001979  |  Val Loss: 0.004380
# Epoch [193/200] Train Loss: 0.001847  |  Val Loss: 0.003682
# Epoch [194/200] Train Loss: 0.001644  |  Val Loss: 0.003828
# Epoch [195/200] Train Loss: 0.001649  |  Val Loss: 0.003874
# Epoch [196/200] Train Loss: 0.001688  |  Val Loss: 0.003765
# Epoch [197/200] Train Loss: 0.001677  |  Val Loss: 0.003779
# Epoch [198/200] Train Loss: 0.001671  |  Val Loss: 0.003813
# Epoch [199/200] Train Loss: 0.001723  |  Val Loss: 0.003936
# Epoch [200/200] Train Loss: 0.001719  |  Val Loss: 0.003758
# Training finished. Logs saved to ./logs/exp39

# %%
# Cell 7: load model

add_safe_globals([DilatedResBlock, Dilated_CNN_ResNet])

model_path = "./model/exp{}/Dilated_ResNet_{}.pth".format(num_exp, num_epochs)
print("Loading model:", model_path)

model = torch.load(model_path, map_location=device, weights_only=False)
# Out:
# Loading model: ./model/exp39/Dilated_ResNet_200.pth

# %%
# Cell 8: validation visualization (merged, keep only the 3x2 figure)

model.eval()

vis_indices = [101, 102, 103]

fig, axes = plt.subplots(3, 2, figsize=(13, 11))
fig.suptitle("Validation Set: Multi-Gaussian Reconstruction under Finite Bandwidth", fontsize=15)

for row, idx in enumerate(vis_indices):
    img, tgt = val_dataset[idx]
    img = img.unsqueeze(0).to(device)
    tgt = l1_nonneg_normalize(tgt.squeeze().cpu().numpy())

    with torch.no_grad():
        pred = model(img).squeeze().cpu().numpy()
    pred = l1_nonneg_normalize(pred)

    z = np.arange(len(tgt)) * dx_um

    ax_left = axes[row, 0]
    ax_left.plot(z, tgt, linewidth=2, label="True")
    ax_left.plot(z, pred, "--", linewidth=2, color="orange", label="Reconstruction")
    ax_left.set_xlabel("z (μm)")
    ax_left.set_ylabel("Normalized charge")
    ax_left.set_title(f"Validation Sample {idx}")
    ax_left.grid(True)
    ax_left.legend()

    k_rec, F2_rec = compute_form_factor(z, pred, pad_factor=pad_factor)
    freq_rec = k_to_THz(k_rec)

    mask_full = (freq_rec >= 0) & (freq_rec <= f_display_max)
    freq_full = freq_rec[mask_full]
    F2_full = F2_rec[mask_full]

    spectrum_measured = img.squeeze().cpu().numpy()
    freq_meas = np.linspace(f_min, f_max, len(spectrum_measured))

    mask_band_full = (freq_full >= f_min) & (freq_full <= f_max)
    scale_forward = np.max(F2_full[mask_band_full]) if np.any(mask_band_full) else np.max(F2_full)
    scale_measured = np.max(spectrum_measured)

    scale_forward = scale_forward if scale_forward > 0 else 1.0
    scale_measured = scale_measured if scale_measured > 0 else 1.0

    ax_right = axes[row, 1]
    ax_right.axvspan(0, f_min, color="blue", alpha=0.08)
    ax_right.axvspan(f_max, f_display_max, color="blue", alpha=0.08)
    ax_right.plot(freq_meas, spectrum_measured / scale_measured, linewidth=2, label="True")
    ax_right.plot(freq_full, F2_full / scale_forward, "--", linewidth=2, color="orange", label="Reconstruction")
    ax_right.set_xlim(0, f_display_max)
    ax_right.set_xlabel("Frequency (THz)")
    ax_right.set_ylabel("Normalized |F|² (band-max)")
    ax_right.set_title("Spectral Consistency")
    ax_right.grid(True)
    ax_right.legend()

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
# Cell 9: CNN Noise Robustness (Peak-weighted error)

model.eval()

box_main = "#3A6EA5"
box_fill = "#9DBBD9"
median_color = "#2C4E73"

# -----------------------------------------
# Select one double-Gaussian sample
# -----------------------------------------
rand_idx = 101


img, tgt = val_dataset[rand_idx]
img = img.unsqueeze(0).to(device)
tgt = tgt.squeeze().cpu().numpy()

N = len(tgt)
z = np.arange(N) * dx_um

# ---- L1 normalization ----
tgt = np.clip(tgt, 0, None)
tgt_norm = tgt / np.sum(tgt)
tgt_norm_max = tgt_norm / np.max(tgt_norm)

# -----------------------------------------
# FWHM alignment
# -----------------------------------------
c_true = fwhm_center(tgt_norm_max, z)

# -----------------------------------------
# Representative reconstructions (LEFT 不动)
# -----------------------------------------
rep_levels = [1e-4, 1e-3, 1e-2]
rep_profiles = []

for nl in rep_levels:

    torch.manual_seed(0)
    noise = nl * torch.randn_like(img)
    img_noisy = torch.clamp(img + noise, min=0.0)

    with torch.no_grad():
        pred = model(img_noisy).squeeze().cpu().numpy()

    pred = np.clip(pred, 0, None)
    pred = pred / np.sum(pred)

    pred_aligned = align_by_fwhm(pred, z, c_true, dx_um)
    rep_profiles.append((nl, pred_aligned))

# -----------------------------------------
# New error metric (peak-weighted L2)
# -----------------------------------------

# 权重 = true profile（强调结构）
weight = tgt_norm
weight = weight / np.max(weight)

# -----------------------------------------
# Statistical scan
# -----------------------------------------
noise_levels = np.logspace(-4, -2, 15)
n_trials = 50
all_errors = []

for nl in noise_levels:

    trial_errors = []

    for seed in range(n_trials):

        torch.manual_seed(seed)
        noise = nl * torch.randn_like(img)
        img_noisy = torch.clamp(img + noise, min=0.0)

        with torch.no_grad():
            pred = model(img_noisy).squeeze().cpu().numpy()

        pred = np.clip(pred, 0, None)
        pred = pred / np.sum(pred)

        pred_aligned = align_by_fwhm(pred, z, c_true, dx_um)

        err = weighted_error(pred_aligned, tgt_norm, weight)
        trial_errors.append(err)

    all_errors.append(trial_errors)

# =========================================
# Plot
# =========================================

fig, axes = plt.subplots(1, 2, figsize=(13, 5))

# ---- LEFT (不动) ----
ax1 = axes[0]

ax1.plot(z, tgt_norm, "k--", linewidth=2, label="Ground truth")

for nl, r in rep_profiles:
    ax1.plot(z, r, linewidth=2, label=f"{nl*100:.2f}% noise")

ax1.set_xlabel("z (μm)")
ax1.set_ylabel("Normalized charge")
ax1.set_title("CNN reconstruction under spectral noise")
ax1.legend(frameon=False)
ax1.grid(alpha=0.3)

# ---- RIGHT (new metric) ----
ax2 = axes[1]

idx = np.arange(len(noise_levels))

box = ax2.boxplot(
    all_errors,
    positions=idx,
    widths=0.6,
    patch_artist=True,
    showfliers=False,
    medianprops=dict(color=median_color, linewidth=2),
    whiskerprops=dict(color=box_main, linewidth=1.5),
    capprops=dict(color=box_main, linewidth=1.5),
    boxprops=dict(color=box_main, linewidth=1.5),
)

for patch in box["boxes"]:
    patch.set_facecolor(box_fill)
    patch.set_alpha(0.6)

medians = [np.median(e) for e in all_errors]
ax2.plot(idx, medians, color=median_color, linewidth=2.2, marker="o", markersize=4)

ax2.set_xlabel("Noise level")
ax2.set_ylabel("Peak-weighted relative error")
ax2.set_title("Structure preservation under spectral noise")

ax2.set_xticks([0, 7, 14])
ax2.set_xticklabels([r"$10^{-4}$", r"$10^{-3}$", r"$10^{-2}$"])

ax2.grid(axis="y", linestyle="--", alpha=0.25)

plt.tight_layout()
plt.show()

# %%
# Cell 10: CNN (unchanged) + GS (Figure2-style forward)

model.eval()

gs_iters = 2000
gs_seed = 1
use_support = True
support_width_um = 30

vis_indices = [101, 102, 103]

# -----------------------------------------
# Timing containers
# -----------------------------------------
nn_times = []
gs_times = []

# -----------------------------------------
# Create figure
# -----------------------------------------
fig, axes = plt.subplots(3, 1, figsize=(10, 12))

for ax, i in zip(axes, vis_indices):

    img, tgt = val_dataset[i]
    img = img.unsqueeze(0).to(device)
    tgt_np = tgt.squeeze().cpu().numpy()

    tgt_np = np.clip(tgt_np, 0, None)
    tgt_np = tgt_np / np.sum(tgt_np)

    # ===============================
    # CNN timing
    # ===============================
    torch.cuda.synchronize() if device.type == "cuda" else None
    start_nn = time.perf_counter()

    with torch.no_grad():
        pred_cnn = model(img)

    torch.cuda.synchronize() if device.type == "cuda" else None
    end_nn = time.perf_counter()

    nn_time_ms = (end_nn - start_nn) * 1000
    nn_times.append(nn_time_ms)

    pred_cnn = pred_cnn.squeeze().cpu().numpy()
    pred_cnn = np.clip(pred_cnn, 0, None)
    pred_cnn = pred_cnn / np.sum(pred_cnn)

    # -----------------------------------------
    # GS forward
    # -----------------------------------------
    rho_true = torch.tensor(tgt_np, dtype=torch.float32, device=device)

    I_meas, _ = forward_spectrum_fft(rho_true)
    I_meas = I_meas.real
    I_meas = I_meas / torch.max(I_meas)

    N = rho_true.numel()
    z_um = (np.arange(N) - N // 2) * dx_um

    if use_support:
        support_mask_np = (np.abs(z_um) <= support_width_um / 2).astype(np.float32)
        support_mask = torch.tensor(support_mask_np, dtype=torch.float32, device=device)
    else:
        support_mask = None

    torch.manual_seed(gs_seed)

    # ===============================
    # GS timing
    # ===============================
    torch.cuda.synchronize() if device.type == "cuda" else None
    start_gs = time.perf_counter()

    rho_gs = gerchberg_saxton_1d_torch(
        I_meas=I_meas,
        n_iters=gs_iters,
        support_mask=support_mask,
        smooth=True,
        device=device,
    )

    torch.cuda.synchronize() if device.type == "cuda" else None
    end_gs = time.perf_counter()

    gs_time_ms = (end_gs - start_gs) * 1000
    gs_times.append(gs_time_ms)

    rho_gs = rho_gs.detach().cpu().numpy()
    rho_gs = np.clip(rho_gs, 0, None)
    rho_gs = rho_gs / np.sum(rho_gs)

    # -----------------------------------------
    # Plot
    # -----------------------------------------
    ax.plot(z_um, tgt_np, linewidth=2, label="Target (Val)")
    ax.plot(z_um, pred_cnn, linestyle="--", linewidth=2, label="CNN")
    ax.plot(z_um, rho_gs, linestyle="-.", linewidth=2,
            label=f"GS (seed={gs_seed}, iters={gs_iters}"
                  + (f", support={support_width_um}μm" if use_support else "") + ")")

    ax.set_xlabel("z (μm)")
    ax.set_ylabel("L1-normalized ρ(z)")
    ax.set_title(f"Validation Sample {i}")
    ax.grid(True)
    ax.legend()

plt.tight_layout()
plt.show()

# =========================================
# Timing statistics
# =========================================

nn_times = np.array(nn_times)
gs_times = np.array(gs_times)

print("=========================================")
print("Timing statistics over selected samples")
print("=========================================")
print(f"GS (2000 iterations):           {gs_times.mean():.2f} ± {gs_times.std():.2f} ms")
print(f"Neural network (1 forward pass):{nn_times.mean():.2f} ± {nn_times.std():.2f} ms")
# Out:
# =========================================
# Timing statistics over selected samples
# =========================================
# GS (2000 iterations):           738.89 ± 184.50 ms
# Neural network (1 forward pass):1.33 ± 0.18 ms

# %%
# Cell 11: BubbleWrap preprocessing only

folder = "./app/form factor/bubble wrap"
target_points = 256

file_order = [
    "F1.csv", "F2.csv", "F3.csv",
    "rho1.csv", "rho2.csv", "rho3.csv"
]

F_list = []
rho_list = []

resample = resample_linear

for filename in file_order:
    path = os.path.join(folder, filename)
    data = pd.read_csv(path)

    x = data.iloc[:, 0].values.astype(float)
    y = data.iloc[:, 1].values.astype(float)

    if filename.startswith("F"):
        omega = x * 1e14
        freq_THz = omega / (2 * np.pi) / 1e12

        mask = (freq_THz >= 50) & (freq_THz <= 230)
        freq_crop = freq_THz[mask]
        y_crop = y[mask]

        y_crop = y_crop / np.max(np.abs(y_crop))
        _, y_res = resample(freq_crop, y_crop, target_points)

        F_list.append(y_res.copy())

    else:
        index_coord = x / dx_um
        index_coord = np.round(index_coord).astype(int)

        sort_idx = np.argsort(index_coord)
        index_coord = index_coord[sort_idx]
        y_sorted = y[sort_idx]

        idx_min = index_coord.min()
        idx_max = index_coord.max()

        full_index = np.arange(idx_min, idx_max + 1)
        full_rho = np.zeros_like(full_index, dtype=float)
        full_rho[index_coord - idx_min] = y_sorted

        full_rho = full_rho / np.max(np.abs(full_rho))

        current_len = len(full_rho)
        if current_len > target_points:
            start = (current_len - target_points) // 2
            full_rho = full_rho[start:start + target_points]
        else:
            pad_total = target_points - current_len
            pad_left = pad_total // 2
            pad_right = pad_total - pad_left
            full_rho = np.pad(full_rho, (pad_left, pad_right))

        rho_list.append(full_rho.copy())

print("Loaded BubbleWrap data:")
print("len(F_list)   =", len(F_list))
print("len(rho_list) =", len(rho_list))
print("F shape       =", np.array(F_list).shape)
print("rho shape     =", np.array(rho_list).shape)
# Out:
# Loaded BubbleWrap data:
# len(F_list)   = 3
# len(rho_list) = 3
# F shape       = (3, 256)
# rho shape     = (3, 256)

# %%
# Cell 12: BubbleWrap → CNN Reconstruction

model.eval()

fig, axes = plt.subplots(2, 3, figsize=(15, 8))
fig.suptitle("BubbleWrap → CNN Reconstruction", fontsize=15)

titles = ["Profile 1", "Profile 2", "Profile 3"]

for col in range(3):

    # === 直接使用 Cell18 的结果 ===
    F_np = F_list[col]
    rho_np = rho_list[col]

    # 转成 tensor 输入模型
    img = torch.tensor(F_np * F_np, dtype=torch.float32).unsqueeze(0).to(device)
    tgt = rho_np  # numpy

    # forward
    with torch.no_grad():
        pred = model(img).squeeze().cpu().numpy()

    # ================= TOP ROW: profile =================
    N = len(tgt)
    z = np.arange(N) * dx_um

    ax_top = axes[0, col]
    ax_top.plot(z, tgt, linewidth=2, label="BubbleWrap")
    ax_top.plot(z, pred, '--', linewidth=2, color='orange', label="CNN Reconstruction")
    ax_top.set_xlabel("z (μm)")
    ax_top.set_ylabel("Normalized charge")
    ax_top.set_title(titles[col])
    ax_top.grid(True)
    ax_top.legend()

    # ================= BOTTOM ROW: spectrum =================
    k_rec, F2_rec = compute_form_factor(z, pred, pad_factor=pad_factor)
    freq_rec = k_to_THz(k_rec)

    mask_full = (freq_rec >= 0) & (freq_rec <= f_display_max)
    freq_full = freq_rec[mask_full]
    F2_full = F2_rec[mask_full]

    spectrum_measured = F_np * F_np
    freq_meas = np.linspace(f_min, f_max, len(spectrum_measured))

    mask_band_full = (freq_full >= f_min) & (freq_full <= f_max)
    if np.any(mask_band_full):
        scale_forward = np.max(F2_full[mask_band_full])
    else:
        scale_forward = np.max(F2_full)

    scale_measured = np.max(spectrum_measured)

    scale_forward = scale_forward if scale_forward > 0 else 1.0
    scale_measured = scale_measured if scale_measured > 0 else 1.0

    ax_bottom = axes[1, col]

    ax_bottom.axvspan(0, f_min, color='blue', alpha=0.08)
    ax_bottom.axvspan(f_max, f_display_max, color='blue', alpha=0.08)

    ax_bottom.plot(
        freq_full,
        F2_full / scale_forward,
        '--',
        linewidth=2,
        color='orange',
        label="Forward (CNN)"
    )

    ax_bottom.plot(
        freq_meas,
        spectrum_measured / scale_measured,
        linewidth=2,
        label="Measured spectrum"
    )

    ax_bottom.set_xlim(0, f_display_max)
    ax_bottom.set_xlabel("Frequency (THz)")
    ax_bottom.set_ylabel("Normalized |F|² (band-max)")
    ax_bottom.set_title("Spectral Consistency")
    ax_bottom.grid(True)
    ax_bottom.legend()

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
