# %%
# Cell 1: imports & basic config

import os
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
from torch.utils.tensorboard import SummaryWriter


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# Cell 2: paths & hyperparameters

img_folder    = "./dataset/G2RP_100_800_2_5_1_3_20_40_05_3_30000/img"      # form factor 
target_folder = "./dataset/G2RP_100_800_2_5_1_3_20_40_05_3_30000/target"   # bunch profile 

sequence_length = 1024       
batch_size = 256
num_epochs = 200
learning_rate = 1e-3
val_ratio = 0.2

# %%
# Cell 3: collect and match file lists

img_files = sorted([f for f in os.listdir(img_folder) if f.endswith(".csv")])
tgt_files = sorted([f for f in os.listdir(target_folder) if f.endswith(".csv")])

print("Number of img files   :", len(img_files))
print("Number of target files:", len(tgt_files))

assert len(img_files) == len(tgt_files), "img 和 target 文件数量不一致！"


for i in range(min(3, len(img_files))):
    print(f"Pair {i}: img={img_files[i]}  <->  target={tgt_files[i]}")
# Out:
# Number of img files   : 30000
# Number of target files: 30000
# Pair 0: img=G2RP_10000_Q1_644.763_s1_4.985_Q2_482.023_s2_1.046_ratioc_1.338_d_30.96_FF.csv  <->  target=G2RP_10000_Q1_644.763_s1_4.985_Q2_482.023_s2_1.046_ratioc_1.338_d_30.96.csv
# Pair 1: img=G2RP_10001_Q1_640.830_s1_3.883_Q2_238.431_s2_2.564_ratioc_2.688_d_20.67_FF.csv  <->  target=G2RP_10001_Q1_640.830_s1_3.883_Q2_238.431_s2_2.564_ratioc_2.688_d_20.67.csv
# Pair 2: img=G2RP_10002_Q1_596.204_s1_4.637_Q2_571.611_s2_2.979_ratioc_1.043_d_39.35_FF.csv  <->  target=G2RP_10002_Q1_596.204_s1_4.637_Q2_571.611_s2_2.979_ratioc_1.043_d_39.35.csv

# %%
# Cell 4: custom Dataset

class CTRDataset(Dataset):
    def __init__(self, img_folder, tgt_folder, img_files, tgt_files, seq_len=1024):
        self.img_folder = img_folder
        self.tgt_folder = tgt_folder
        self.img_files = img_files
        self.tgt_files = tgt_files
        self.seq_len = seq_len

    def __len__(self):
        return len(self.img_files)

    def __getitem__(self, idx):
        img_path = os.path.join(self.img_folder, self.img_files[idx])
        tgt_path = os.path.join(self.tgt_folder, self.tgt_files[idx])

        # read form factor
        df_img = pd.read_csv(img_path)
        # read "F2"
        F2 = df_img.iloc[:, 1].values if "F2" not in df_img.columns else df_img["F2"].values
        
        # read bunch profile
        df_tgt = pd.read_csv(tgt_path)
        # read "Intensity"
        y = df_tgt.iloc[:, 1].values if "Intensity" not in df_tgt.columns else df_tgt["Intensity"].values

        # seq_len
        assert len(F2) == self.seq_len, f"Form factor length {len(F2)} != {self.seq_len}"
        assert len(y)  == self.seq_len, f"Bunch length {len(y)} != {self.seq_len}"

        # normalize to 0-1
        F2_norm = F2 / (F2.max() + 1e-8)
        y_norm  = y  / (y.max()  + 1e-8)

        # to tensor
        img_tensor = torch.tensor(F2_norm, dtype=torch.float32).unsqueeze(0)  # (1, L)
        tgt_tensor = torch.tensor(y_norm,  dtype=torch.float32).unsqueeze(0)  # (1, L)

        return img_tensor, tgt_tensor

# 创建完整数据集
full_dataset = CTRDataset(img_folder, target_folder, img_files, tgt_files, seq_len=sequence_length)
print("Total samples in dataset:", len(full_dataset))
# Out:
# Total samples in dataset: 30000

# %%
# Cell 5: split into train / val and create DataLoaders

num_total = len(full_dataset)
num_val = int(num_total * val_ratio)
num_train = num_total - num_val

train_dataset, val_dataset = random_split(full_dataset, [num_train, num_val])

print(f"Train samples: {num_train}, Val samples: {num_val}")

train_loader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,
    # num_workers=4,          
    # pin_memory=True,        
    # persistent_workers=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=batch_size,
    shuffle=False,
    # num_workers=4,
    # pin_memory=True,
    # persistent_workers=True
)
# Out:
# Train samples: 24000, Val samples: 6000

# %%
# Cell 6: define 1D Dilated ResNet for CTR inverse

class DilatedResBlock(nn.Module):
    def __init__(self, ch, kernel_size=5, dilation=1):
        super().__init__()
        pad = (kernel_size // 2) * dilation

        self.conv = nn.Sequential(
            nn.Conv1d(ch, ch, kernel_size,
                      padding=pad, dilation=dilation),
            nn.ReLU(inplace=True),
            nn.Conv1d(ch, ch, kernel_size,
                      padding=pad, dilation=dilation),
        )
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        return self.relu(x + self.conv(x))  # residual


class Dilated_ResNet(nn.Module):
    def __init__(self, in_ch=1, base_ch=64):
        super().__init__()

        # first layer
        self.in_conv = nn.Conv1d(in_ch, base_ch, kernel_size=3, padding=1)

        # 6 dilated residual blocks
        self.block1 = DilatedResBlock(base_ch, dilation=1)
        self.block2 = DilatedResBlock(base_ch, dilation=2)
        self.block3 = DilatedResBlock(base_ch, dilation=4)
        self.block4 = DilatedResBlock(base_ch, dilation=8)
        self.block5 = DilatedResBlock(base_ch, dilation=16)
        self.block6 = DilatedResBlock(base_ch, dilation=32)

        # output
        self.out_conv = nn.Conv1d(base_ch, 1, kernel_size=1)

    def forward(self, x):
        x = self.in_conv(x)
        x = self.block1(x)
        x = self.block2(x)
        x = self.block3(x)
        x = self.block4(x)
        x = self.block5(x)
        x = self.block6(x)
        x = self.out_conv(x)
        return x


model = Dilated_ResNet(in_ch=1, base_ch=64).to(device)

print(model)
# Out:
# Dilated_ResNet(
#   (in_conv): Conv1d(1, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#   (block1): DilatedResBlock(
#     (conv): Sequential(
#       (0): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#       (1): ReLU(inplace=True)
#       (2): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (block2): DilatedResBlock(
#     (conv): Sequential(
#       (0): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(4,), dilation=(2,))
#       (1): ReLU(inplace=True)
#       (2): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(4,), dilation=(2,))
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (block3): DilatedResBlock(
#     (conv): Sequential(
#       (0): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(8,), dilation=(4,))
#       (1): ReLU(inplace=True)
#       (2): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(8,), dilation=(4,))
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (block4): DilatedResBlock(
#     (conv): Sequential(
#       (0): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(16,), dilation=(8,))
#       (1): ReLU(inplace=True)
#       (2): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(16,), dilation=(8,))
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (block5): DilatedResBlock(
#     (conv): Sequential(
#       (0): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(32,), dilation=(16,))
#       (1): ReLU(inplace=True)
#       (2): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(32,), dilation=(16,))
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (block6): DilatedResBlock(
#     (conv): Sequential(
#       (0): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(64,), dilation=(32,))
#       (1): ReLU(inplace=True)
#       (2): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(64,), dilation=(32,))
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (out_conv): Conv1d(64, 1, kernel_size=(1,), stride=(1,))
# )

# %%
# Cell 7: training & validation loops

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

def train_one_epoch(model, loader, optimizer, criterion, device):
    model.train()
    running_loss = 0.0
    for img, tgt in loader:
        img = img.to(device)   # (B,1,L)
        tgt = tgt.to(device)   # (B,1,L)

        optimizer.zero_grad()
        pred = model(img)
        loss = criterion(pred, tgt)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * img.size(0)
    return running_loss / len(loader.dataset)

def evaluate(model, loader, criterion, device):
    model.eval()
    running_loss = 0.0
    with torch.no_grad():
        for img, tgt in loader:
            img = img.to(device)
            tgt = tgt.to(device)
            pred = model(img)
            loss = criterion(pred, tgt)
            running_loss += loss.item() * img.size(0)
    return running_loss / len(loader.dataset)

# %%
# Cell 8: run training with TensorBoard logging

# create TensorBoard logs
writer = SummaryWriter(log_dir="./logs/exp8")

train_losses = []
val_losses = []

for epoch in range(1, num_epochs + 1):

    train_loss = train_one_epoch(model, train_loader, optimizer, criterion, device)
    val_loss   = evaluate(model, val_loader, criterion, device)

    train_losses.append(train_loss)
    val_losses.append(val_loss)

    # TensorBoard
    writer.add_scalar("Loss/train", train_loss, epoch)
    writer.add_scalar("Loss/val",   val_loss, epoch)

    print(f"Epoch [{epoch:03d}/{num_epochs}] "
          f"Train Loss: {train_loss:.6f}  |  Val Loss: {val_loss:.6f}")
    
    torch.save(model, "./model/exp8/Dilated_ResNet_{}.pth".format(epoch))

writer.close()
print("Training finished. Logs saved to ./logs/exp8")
# Out:
# Epoch [001/200] Train Loss: 0.000942  |  Val Loss: 0.000889
# Epoch [002/200] Train Loss: 0.000836  |  Val Loss: 0.000797
# Epoch [003/200] Train Loss: 0.000906  |  Val Loss: 0.000903
# Epoch [004/200] Train Loss: 0.000844  |  Val Loss: 0.000758
# Epoch [005/200] Train Loss: 0.000810  |  Val Loss: 0.001138
# Epoch [006/200] Train Loss: 0.000897  |  Val Loss: 0.000770
# Epoch [007/200] Train Loss: 0.000898  |  Val Loss: 0.000876
# Epoch [008/200] Train Loss: 0.000865  |  Val Loss: 0.000837
# Epoch [009/200] Train Loss: 0.000847  |  Val Loss: 0.000839
# Epoch [010/200] Train Loss: 0.000833  |  Val Loss: 0.000826
# Epoch [011/200] Train Loss: 0.000850  |  Val Loss: 0.000816
# Epoch [012/200] Train Loss: 0.000944  |  Val Loss: 0.000810
# Epoch [013/200] Train Loss: 0.000880  |  Val Loss: 0.000862
# Epoch [014/200] Train Loss: 0.000903  |  Val Loss: 0.000830
# Epoch [015/200] Train Loss: 0.000796  |  Val Loss: 0.000909
# Epoch [016/200] Train Loss: 0.000826  |  Val Loss: 0.000787
# Epoch [017/200] Train Loss: 0.001015  |  Val Loss: 0.000797
# Epoch [018/200] Train Loss: 0.000878  |  Val Loss: 0.000883
# Epoch [019/200] Train Loss: 0.000787  |  Val Loss: 0.000762
# Epoch [020/200] Train Loss: 0.000846  |  Val Loss: 0.000789
# Epoch [021/200] Train Loss: 0.000823  |  Val Loss: 0.000889
# Epoch [022/200] Train Loss: 0.000867  |  Val Loss: 0.000990
# Epoch [198/200] Train Loss: 0.000729  |  Val Loss: 0.000676
# Epoch [199/200] Train Loss: 0.000690  |  Val Loss: 0.000777
# Epoch [200/200] Train Loss: 0.000694  |  Val Loss: 0.000746
# Training finished. Logs saved to ./logs/exp8

# %%
# # Cell 9: write pred vs target to TensorBoard without any plotting library

# # 再创建 writer（或复用之前的）
# writer = SummaryWriter(log_dir="./logs/seed5")

# model.eval()

# # 取一个 batch
# img_batch, tgt_batch = next(iter(val_loader))
# img_batch = img_batch.to(device)
# tgt_batch = tgt_batch.to(device)

# with torch.no_grad():
#     pred_batch = model(img_batch)

# # 取第一条样本
# img_np  = img_batch[0, 0].cpu().numpy()
# tgt_np  = tgt_batch[0, 0].cpu().numpy()
# pred_np = pred_batch[0, 0].cpu().numpy()

# # -------------------------------
# # 函数：把曲线画在一个 NumPy 图片里
# # -------------------------------
# def draw_waveform(curves, colors, H=256, W=1024):
#     """
#     curves: list of np arrays of shape (L,)
#     colors: list of (R,G,B)
#     """
#     img = np.ones((H, W, 3), dtype=np.uint8) * 255   # white canvas

#     # 每条曲线归一化到高度范围
#     for curve, color in zip(curves, colors):

#         # normalize curve to [0,1]
#         c = curve.copy()
#         c = (c - c.min()) / (c.max() - c.min() + 1e-8)

#         # map to pixel coords
#         ys = (H - 1) - (c * (H - 1)).astype(np.int32)   # vertical flip (top=0)
#         xs = np.linspace(0, W-1, len(c)).astype(np.int32)

#         # draw pixel points
#         for x, y in zip(xs, ys):
#             img[y, x] = color

#     return img


# # ============ 图像 1：Pred vs Target（两条曲线） =============
# waveform1 = draw_waveform(
#     curves=[tgt_np, pred_np],
#     colors=[(255, 0, 0), (0, 0, 255)],   # red target, blue pred
#     H=256, W=1024
# )

# # ============ 图像 2：Input |F|² =============
# waveform2 = draw_waveform(
#     curves=[img_np],
#     colors=[(128, 0, 128)],             # purple
#     H=256, W=1024
# )

# # 写入 TensorBoard
# writer.add_image("Waveform/target_vs_pred", waveform1, dataformats="HWC")
# writer.add_image("Waveform/input_F2",       waveform2, dataformats="HWC")

# writer.close()

# print("Pure NumPy waveforms written to TensorBoard.")
# Out:
# Pure NumPy waveforms written to TensorBoard.

# %%
# Cell 9: load epoch-180 model and test prediction

import matplotlib.pyplot as plt
from torch.serialization import add_safe_globals
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

add_safe_globals([Dilated_ResNet])

model_path = "./model/exp8/Dilated_ResNet_200.pth"
print("Loading model:", model_path)

model_180 = torch.load(model_path, map_location=device, weights_only=False)
model_180.eval()

for idx in range(50):
    img, tgt = full_dataset[idx]

    img = img.unsqueeze(0).to(device)     # (1,1,1024)
    tgt = tgt.squeeze().cpu().numpy()     # (1024,)

    with torch.no_grad():
        pred = model_180(img).squeeze().cpu().numpy()   # (1024,)

    # （5）画图：target vs pred
    plt.figure(figsize=(10,4))
    plt.plot(tgt, label="Target", linewidth=2)
    plt.plot(pred, label="Predicted", linestyle='--')
    plt.xlabel("Index")
    plt.ylabel("Normalized value")
    plt.title("Prediction using model epoch 400")
    plt.grid(True)
    plt.legend()
    plt.show()
# Out:
# Loading model: ./model/exp8/Dilated_ResNet_200.pth
